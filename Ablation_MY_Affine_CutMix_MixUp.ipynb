# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/MS_Trust/blob/main/Ablation_MY_Affine_CutMix_MixUp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Ablation study: MS-Trust: MixUp and CutMix
# *   Axial & Sagittal
# *   MY-DS (MY/MS/TC) dataset

# %%
# !pip install -U -q tensorflow-addons
# !pip install nest_asyncio
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.1/612.1 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (1.5.7)

# %%
import os
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.preprocessing import image_dataset_from_directory

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np
from google.colab import drive

# Define the path to the MRI data directory
drive.mount('/content/drive', force_remount=True)

import nest_asyncio

# %% [markdown]
# # 🈺 Hyperparameters

# %%
######################
NUM_CLASSES = 3
######################
positional_emb = True
conv_layers = 2
projection_dim = 128
num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
stochastic_depth_rate = 0.1
learning_rate = 0.001
weight_decay = 0.0001
NUM_EPOCHS = 100
IMG_SIZE =224
BATCH_SIZE = 32
input_shape = (224, 224, 3)

np.random.seed(42)
tf.random.set_seed(42)
AUTO = tf.data.AUTOTUNE

# %%
def preprocess_image(path):
    image = tf.keras.utils.load_img(path)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = tf.image.convert_image_dtype(image, tf.float32) / 255.0
    return image

# %%
plt.imshow(preprocess_image(os.path.join("/content/drive/MyDrive/Myelitis_Dataset_Three_Classes/myelitis/", "1 (1).jpg" )))

# %%
def plot_training_curves(history, title):
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])
    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])
    epochs = range(len(history.history['loss']))
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='.')
    ax1.plot(epochs, val_loss, label='val_loss', marker='.')
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)
    ax1.set_title('Loss: '+title, fontsize=16)
    ax1.set_xlabel('Epochs', fontsize=14)
    ax1.legend()

    # Plot accuracy
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='.')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='.')
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)
    ax2.set_title('Accuracy: '+title, fontsize=16)
    ax2.set_xlabel('Epochs', fontsize=14)
    ax2.legend();

# %% [markdown]
# ---
# # 🧠 Load Myelitis Dataset

# %%
# Folder "TC" consist of MRI scans having Typical subjects (with no MS)
nest_asyncio.apply()
TC_scan_paths = [
    os.path.join(os.getcwd(), "/content/drive/MyDrive/Myelitis_Dataset_Three_Classes/control/", x)
    for x in os.listdir("/content/drive/MyDrive/Myelitis_Dataset_Three_Classes/control/")
]
# Folder "MS" consist of MRI scans having several MS
nest_asyncio.apply()
MS_scan_paths = [
    os.path.join(os.getcwd(), "/content/drive/MyDrive/Myelitis_Dataset_Three_Classes/ms/", x)
    for x in os.listdir("/content/drive/MyDrive/Myelitis_Dataset_Three_Classes/ms/")
]
# Folder "MY" consist of MRI scans having several Myelitis
nest_asyncio.apply()
MY_scan_paths = [
    os.path.join(os.getcwd(), "/content/drive/MyDrive/Myelitis_Dataset_Three_Classes/myelitis/", x)
    for x in os.listdir("/content/drive/MyDrive/Myelitis_Dataset_Three_Classes/myelitis/")
]
n_TC = len(TC_scan_paths)
n_MS = len(MS_scan_paths)
n_MY = len(MY_scan_paths)
r_TC = round(n_TC * 0.8)
r_MS = round(n_MS * 0.8)
r_MY = round(n_MY * 0.8)
print("MRI scans with TC: " + str(n_TC) + ' round: ' + str(r_TC))
print("MRI scans with MS: " + str(n_MS) + ' round: ' + str(r_MS))
print("MRI scans with MY: " + str(n_MY) + ' round: ' + str(r_MY))
# Out:
# MRI scans with TC: 1398 round: 1118
# MRI scans with MS: 667 round: 534
# MRI scans with MY: 706 round: 565

# %%
# Read and process the scans.
# Each scan is resized across height, width, and depth and rescaled.
nest_asyncio.apply()
TC_scans = np.array([preprocess_image(path)  for path in TC_scan_paths])
nest_asyncio.apply()
MS_scans = np.array([preprocess_image(path) for path in MS_scan_paths])
nest_asyncio.apply()
MY_scans = np.array([preprocess_image(path) for path in MY_scan_paths])

# %%
# For the scans having presence of MS assign 1, MY assign 2, for the typical control TC ones assign 0.
nest_asyncio.apply()
TC_labels = np.array([0 for _ in range(len(TC_scans))])
nest_asyncio.apply()
MS_labels = np.array([1 for _ in range(len(MS_scans))])
nest_asyncio.apply()
MY_labels = np.array([2 for _ in range(len(MY_scans))])

# Split data in the ratio 80%-20% for training and validation.
x_train1 = np.concatenate((MY_scans[:r_MY], MS_scans[:r_MS]), axis=0)
x_train = np.concatenate((x_train1, TC_scans[:r_TC]), axis=0)
y_train1 = np.concatenate((MY_labels[:r_MY], MS_labels[:r_MS]), axis=0)
y_train = np.concatenate((y_train1, TC_labels[:r_TC]), axis=0)
x_val1 = np.concatenate((MY_scans[r_MY:], MS_scans[r_MS:]), axis=0)
x_val = np.concatenate((x_val1, TC_scans[r_TC:]), axis=0)
y_val1 = np.concatenate((MY_labels[r_MY:], MS_labels[r_MS:]), axis=0)
y_val = np.concatenate((y_val1, TC_labels[r_TC:]), axis=0)
y_train = tf.keras.utils.to_categorical(y_train, num_classes=NUM_CLASSES)
y_val = tf.keras.utils.to_categorical(y_val, num_classes=NUM_CLASSES)
print(
    "Number of samples in train and validation are %d and %d."
    % (x_train.shape[0], x_val.shape[0])
)
# Out:
# Number of samples in train and validation are 2217 and 554.

# %% [markdown]
# # 🅰 Data augmentation
#
# In the original paper, the authors use AutoAugment to induce stronger regularization. For this example, we will be using the standard geometric augmentations like random cropping and flipping. https://arxiv.org/abs/1805.09501

# %%
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  layers.CenterCrop(height=IMG_SIZE, width=IMG_SIZE)
])

# %%
train_ds = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(1024)
)

aug_ds = train_ds.map(
  lambda x, y: (data_augmentation(x, training=True), y))
aug_ds = (
    aug_ds
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

validation_ds = tf.data.Dataset.from_tensor_slices((x_val, y_val))
validation_ds = (
    validation_ds
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

# %% [markdown]
# # 🅰 Define the MixUp function
#
#
# To perform the mixup routine, we create new virtual datasets using the training data from the same dataset, and apply a lambda value within the [0, 1] range sampled from a Beta distribution — such that, for example, new_x = lambda * x1 + (1 - lambda) * x2 (where x1 and x2 are images) and the same equation is applied to the labels as well.

# %%
def sample_beta_distribution(size, concentration_0=0.2, concentration_1=0.2):
    gamma_1_sample = tf.random.gamma(shape=[size], alpha=concentration_1)
    gamma_2_sample = tf.random.gamma(shape=[size], alpha=concentration_0)
    return gamma_1_sample / (gamma_1_sample + gamma_2_sample)

@tf.function
def mix_up(train_ds_one, train_ds_two):
    alpha=0.2
     # Unpack two datasets
    images_one, labels_one = train_ds_one
    images_two, labels_two = train_ds_two
    batch_size = 1

    # Sample lambda and reshape it to do the mixup
    l = sample_beta_distribution(batch_size, alpha, alpha)
    x_l = l
    y_l = l

    # Perform mixup on both images and labels by combining a pair of images/labels
    # (one from each dataset) into one image/label
    images = images_one * x_l + images_two * (1 - x_l)
    labels = labels_one * y_l + labels_two * (1 - y_l)
    return (images, labels)

# %%
train_ds_one_A = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(1024)
)
train_ds_two_A = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(1024)
)
# Combine two shuffled datasets from the same training data.
train_ds_A = tf.data.Dataset.zip((train_ds_one_A, train_ds_two_A))

validation_ds_A = tf.data.Dataset.from_tensor_slices((x_val, y_val))
validation_ds_A = (
    validation_ds_A
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

# Create the new dataset using our `cutmix` utility
train_ds_cmu_A = (
    train_ds_A.shuffle(1024)
    .map(mix_up, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

# %% [markdown]
# # 🅰 Define the CutMix function
#
# ---
#
#
# The CutMix function takes two image and label pairs to perform the augmentation. It samples λ(l) from the Beta distribution and returns a bounding box from get_box function. We then crop the second image (image2) and pad this image in the final padded image at the same location.
#
# *Note: we are combining two images to create a single one*

# %%
def sample_beta_distribution(size, concentration_0=0.2, concentration_1=0.2):
    gamma_1_sample = tf.random.gamma(shape=[size], alpha=concentration_1)
    gamma_2_sample = tf.random.gamma(shape=[size], alpha=concentration_0)
    return gamma_1_sample / (gamma_1_sample + gamma_2_sample)

@tf.function
def get_box(lambda_value):
    cut_rat = tf.math.sqrt(1.0 - lambda_value)
    cut_w = IMG_SIZE * cut_rat  # rw
    cut_w = tf.cast(cut_w, tf.int32)
    cut_h = IMG_SIZE * cut_rat  # rh
    cut_h = tf.cast(cut_h, tf.int32)
    cut_x = tf.random.uniform((1,), minval=0, maxval=IMG_SIZE, dtype=tf.int32)  # rx
    cut_y = tf.random.uniform((1,), minval=0, maxval=IMG_SIZE, dtype=tf.int32)  # ry

    boundaryx1 = tf.clip_by_value(cut_x[0] - cut_w // 2, 0, IMG_SIZE)
    boundaryy1 = tf.clip_by_value(cut_y[0] - cut_h // 2, 0, IMG_SIZE)
    bbx2 = tf.clip_by_value(cut_x[0] + cut_w // 2, 0, IMG_SIZE)
    bby2 = tf.clip_by_value(cut_y[0] + cut_h // 2, 0, IMG_SIZE)

    target_h = bby2 - boundaryy1
    if target_h == 0:
        target_h += 1

    target_w = bbx2 - boundaryx1
    if target_w == 0:
        target_w += 1

    return boundaryx1, boundaryy1, target_h, target_w

@tf.function
def cutmix(train_ds_one, train_ds_two):
    (image1, label1), (image2, label2) = train_ds_one, train_ds_two

    alpha = [0.25]
    beta = [0.25]

    # Get a sample from the Beta distribution
    lambda_value = sample_beta_distribution(1, alpha, beta)

    # Define Lambda
    lambda_value = lambda_value[0][0]

    # Get the bounding box offsets, heights and widths
    boundaryx1, boundaryy1, target_h, target_w = get_box(lambda_value)

    # Get a patch from the second image (`image2`)
    crop2 = tf.image.crop_to_bounding_box(
        image2, boundaryy1, boundaryx1, target_h, target_w
    )
    # Pad the `image2` patch (`crop2`) with the same offset
    image2 = tf.image.pad_to_bounding_box(
        crop2, boundaryy1, boundaryx1, IMG_SIZE, IMG_SIZE
    )
    # Get a patch from the first image (`image1`)
    crop1 = tf.image.crop_to_bounding_box(
        image1, boundaryy1, boundaryx1, target_h, target_w
    )
    # Pad the `image1` patch (`crop1`) with the same offset
    img1 = tf.image.pad_to_bounding_box(
        crop1, boundaryy1, boundaryx1, IMG_SIZE, IMG_SIZE
    )

    # Modify the first image by subtracting the patch from `image1`
    # (before applying the `image2` patch)
    image1 = image1 - img1
    # Add the modified `image1` and `image2`  together to get the CutMix image
    image = image1 + image2

    # Adjust Lambda in accordance to the pixel ration
    lambda_value = 1 - (target_w * target_h) / (IMG_SIZE * IMG_SIZE)
    lambda_value = tf.cast(lambda_value, tf.float32 )

    # Combine the labels of both images
    label = lambda_value * label1 + (1 - lambda_value) * label2
    return image, label

# %%
train_ds_one_B = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(1024)
)
train_ds_two_B = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(1024)
)
# Combine two shuffled datasets from the same training data.
train_ds_B = tf.data.Dataset.zip((train_ds_one_B, train_ds_two_B))

validation_ds_B = tf.data.Dataset.from_tensor_slices((x_val, y_val))
validation_ds_B = (
    validation_ds_B
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

# Create the new dataset using our `cutmix` utility
train_ds_cmu_B = (
    train_ds_B.shuffle(1024)
    .map(cutmix, num_parallel_calls=AUTO)
    .batch(BATCH_SIZE)
    .prefetch(AUTO)
)

# %% [markdown]
# # ♒ Stochastic depth for regularization
#
# Stochastic depth is a regularization technique that randomly drops a set of layers. During inference, the layers are kept as they are. It is very much similar to Dropout but only that it operates on a block of layers rather than individual nodes present inside a layer. In CCT, stochastic depth is used just before the residual blocks of a Transformers encoder.

# %%
# Referred from: github.com:rwightman/pytorch-image-models.
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prop

    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (tf.shape(x).shape[0] - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %% [markdown]
# # ♒ SqueezeExcite & MLP

# %%
class SqueezeExcite(layers.Layer):
    """Applies squeeze and excitation to input feature maps as seen in https://arxiv.org/abs/1709.01507.
    Args:
        ratio: The ratio with which the feature map needs to be reduced in the reduction phase.
    Inputs:
        Convolutional features.
    Outputs:
        Attention modified feature maps.
    """
    def __init__(self, ratio, **kwargs):
        super().__init__(**kwargs)
        self.ratio = ratio

    def get_config(self):
        config = super().get_config()
        config.update({"ratio": self.ratio})
        return config

    def build(self, input_shape):
        filters = input_shape[-1]
        self.squeeze = layers.GlobalAveragePooling2D(keepdims=True)
        self.reduction = layers.Dense(
            units=filters // self.ratio, activation="relu", use_bias=False,
        )
        self.excite = layers.Dense(units=filters, activation="sigmoid", use_bias=False)
        self.multiply = layers.Multiply()

    def call(self, x):
        shortcut = x
        x = self.squeeze(x)
        x = self.reduction(x)
        x = self.excite(x)
        x = self.multiply([shortcut, x])
        return x

################### This is for MS-Trust ##############
def mlp2(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        SqueezeExcite(x)
        x = layers.Dropout(dropout_rate)(x)
    return x
################### This is for CCT ##############
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ---
#
#
# # ✅ Affine
# Use: aug_ds, validation_ds

# %% [markdown]
# # 🈺 Ablation study: #1 Hyperparameters

# %%
#MS-Trust TE=1, SE=1, Conv=2
transformer_layers = 1
squeeze_excite_layers = 1
conv_layers = 2

# %%
#MS-Trust TE=2, SE=1, Conv=2
transformer_layers = 2
squeeze_excite_layers = 1
conv_layers = 2

# %%
#MS-Trust TE=3, SE=1, Conv=2
transformer_layers = 3
squeeze_excite_layers = 1
conv_layers = 2

# %%
#MS-Trust TE=2, SE=2, Conv=2
transformer_layers = 2
squeeze_excite_layers = 2
conv_layers = 2

# %%
#MS-Trust TE=3, SE=2, Conv=2
transformer_layers = 3
squeeze_excite_layers = 2
conv_layers = 2

# %% [markdown]
# # ⛓ The CCT tokenizer
#
# The first recipe introduced by the CCT authors is the tokenizer for processing the images. In a standard ViT, images are organized into uniform non-overlapping patches. This eliminates the boundary-level information present in between different patches. This is important for a neural network to effectively exploit the locality information. The figure below presents an illustration of how images are organized into patches.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We already know that convolutions are quite good at exploiting locality information. So, based on this, the authors introduce an all-convolution mini-network to produce image patches.

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super().__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %% [markdown]
# # ⛓ The final CCT model

# %%
def create_cct_model(
    image_size=IMG_SIZE,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):
    inputs = layers.Input(input_shape)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(inputs)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)

        # MLP.
        x3 = mlp2(x3, hidden_units=transformer_units, dropout_rate=0.1)

        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply SqueezeExcite
    if squeeze_excite_layers == 2:
      encoded_patches = mlp2(encoded_patches, hidden_units=transformer_units, dropout_rate=0.1)

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES , activation="softmax")(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
model = create_cct_model()
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  cct_tokenizer_4 (CCTTokeni  (None, 3136, 128)            75456     ['input_5[0][0]']
#  zer)
#
#  tf.__operators__.add_4 (TF  (None, 3136, 128)            0         ['cct_tokenizer_4[0][0]']
#  OpLambda)
#
#  layer_normalization_20 (La  (None, 3136, 128)            256       ['tf.__operators__.add_4[0][0]
#  yerNormalization)                                                  ']
#
#  multi_head_attention_8 (Mu  (None, 3136, 128)            131968    ['layer_normalization_20[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_20[0][0]
#                                                                     ']
#
#  stochastic_depth_16 (Stoch  (None, 3136, 128)            0         ['multi_head_attention_8[0][0]
#  asticDepth)                                                        ']
#
#  add_16 (Add)                (None, 3136, 128)            0         ['stochastic_depth_16[0][0]',
#                                                                      'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  layer_normalization_21 (La  (None, 3136, 128)            256       ['add_16[0][0]']
#  yerNormalization)
#
#  dense_28 (Dense)            (None, 3136, 128)            16512     ['layer_normalization_21[0][0]
#                                                                     ']
#
#  dropout_20 (Dropout)        (None, 3136, 128)            0         ['dense_28[0][0]']
#
#  dense_29 (Dense)            (None, 3136, 128)            16512     ['dropout_20[0][0]']
#
#  dropout_21 (Dropout)        (None, 3136, 128)            0         ['dense_29[0][0]']
#
#  stochastic_depth_17 (Stoch  (None, 3136, 128)            0         ['dropout_21[0][0]']
#  asticDepth)
#
#  add_17 (Add)                (None, 3136, 128)            0         ['stochastic_depth_17[0][0]',
#                                                                      'add_16[0][0]']
#
#  layer_normalization_22 (La  (None, 3136, 128)            256       ['add_17[0][0]']
#  yerNormalization)
#
#  multi_head_attention_9 (Mu  (None, 3136, 128)            131968    ['layer_normalization_22[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'layer_normalization_22[0][0]
#                                                                     ']
#
#  stochastic_depth_18 (Stoch  (None, 3136, 128)            0         ['multi_head_attention_9[0][0]
#  asticDepth)                                                        ']
#
#  add_18 (Add)                (None, 3136, 128)            0         ['stochastic_depth_18[0][0]',
#                                                                      'add_17[0][0]']
#
#  layer_normalization_23 (La  (None, 3136, 128)            256       ['add_18[0][0]']
#  yerNormalization)
#
#  dense_30 (Dense)            (None, 3136, 128)            16512     ['layer_normalization_23[0][0]
#                                                                     ']
#
#  dropout_22 (Dropout)        (None, 3136, 128)            0         ['dense_30[0][0]']
#
#  dense_31 (Dense)            (None, 3136, 128)            16512     ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)        (None, 3136, 128)            0         ['dense_31[0][0]']
#
#  stochastic_depth_19 (Stoch  (None, 3136, 128)            0         ['dropout_23[0][0]']
#  asticDepth)
#
#  add_19 (Add)                (None, 3136, 128)            0         ['stochastic_depth_19[0][0]',
#                                                                      'add_18[0][0]']
#
#  layer_normalization_24 (La  (None, 3136, 128)            256       ['add_19[0][0]']
#  yerNormalization)
#
#  multi_head_attention_10 (M  (None, 3136, 128)            131968    ['layer_normalization_24[0][0]
#  ultiHeadAttention)                                                 ',
#                                                                      'layer_normalization_24[0][0]
#                                                                     ']
#
#  stochastic_depth_20 (Stoch  (None, 3136, 128)            0         ['multi_head_attention_10[0][0
#  asticDepth)                                                        ]']
#
#  add_20 (Add)                (None, 3136, 128)            0         ['stochastic_depth_20[0][0]',
#                                                                      'add_19[0][0]']
#
#  layer_normalization_25 (La  (None, 3136, 128)            256       ['add_20[0][0]']
#  yerNormalization)
#
#  dense_32 (Dense)            (None, 3136, 128)            16512     ['layer_normalization_25[0][0]
#                                                                     ']
#
#  dropout_24 (Dropout)        (None, 3136, 128)            0         ['dense_32[0][0]']
#
#  dense_33 (Dense)            (None, 3136, 128)            16512     ['dropout_24[0][0]']
#
#  dropout_25 (Dropout)        (None, 3136, 128)            0         ['dense_33[0][0]']
#
#  stochastic_depth_21 (Stoch  (None, 3136, 128)            0         ['dropout_25[0][0]']
#  asticDepth)
#
#  add_21 (Add)                (None, 3136, 128)            0         ['stochastic_depth_21[0][0]',
#                                                                      'add_20[0][0]']
#
#  layer_normalization_26 (La  (None, 3136, 128)            256       ['add_21[0][0]']
#  yerNormalization)
#
#  dense_34 (Dense)            (None, 3136, 1)              129       ['layer_normalization_26[0][0]
#                                                                     ']
#
#  tf.nn.softmax_4 (TFOpLambd  (None, 3136, 1)              0         ['dense_34[0][0]']
#  a)
#
#  tf.linalg.matmul_4 (TFOpLa  (None, 1, 128)               0         ['tf.nn.softmax_4[0][0]',
#  mbda)                                                               'layer_normalization_26[0][0]
#                                                                     ']
#
#  tf.compat.v1.squeeze_4 (TF  (None, 128)                  0         ['tf.linalg.matmul_4[0][0]']
#  OpLambda)
#
#  dense_35 (Dense)            (None, 3)                    387       ['tf.compat.v1.squeeze_4[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 572740 (2.18 MB)
# Trainable params: 572740 (2.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#Re-Run
optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)

model.compile(
    optimizer=optimizer,
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Precision(),
        keras.metrics.Recall(),
        keras.metrics.AUC(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', threshold=0.5),
        ],
    )
history = model.fit(aug_ds,
                    validation_data=validation_ds,
                    batch_size=BATCH_SIZE,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 70/70 [==============================] - 35s 431ms/step - loss: 0.8709 - accuracy: 0.6689 - precision_4: 0.7573 - recall_4: 0.5756 - auc_4: 0.8499 - f1_score: 0.5468 - val_loss: 0.7515 - val_accuracy: 0.6480 - val_precision_4: 0.6839 - val_recall_4: 0.5975 - val_auc_4: 0.8855 - val_f1_score: 0.4870
# Epoch 2/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.7448 - accuracy: 0.7271 - precision_4: 0.7846 - recall_4: 0.6130 - auc_4: 0.8915 - f1_score: 0.5864 - val_loss: 0.6780 - val_accuracy: 0.7130 - val_precision_4: 0.7318 - val_recall_4: 0.6697 - val_auc_4: 0.9164 - val_f1_score: 0.5790
# Epoch 3/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.6689 - accuracy: 0.7564 - precision_4: 0.8040 - recall_4: 0.6996 - auc_4: 0.9220 - f1_score: 0.6676 - val_loss: 0.6486 - val_accuracy: 0.7527 - val_precision_4: 0.8042 - val_recall_4: 0.6968 - val_auc_4: 0.9307 - val_f1_score: 0.6524
# Epoch 4/100
# 70/70 [==============================] - 29s 421ms/step - loss: 0.6833 - accuracy: 0.7479 - precision_4: 0.7914 - recall_4: 0.6946 - auc_4: 0.9159 - f1_score: 0.6556 - val_loss: 0.6741 - val_accuracy: 0.7473 - val_precision_4: 0.7904 - val_recall_4: 0.6534 - val_auc_4: 0.9176 - val_f1_score: 0.6018
# Epoch 5/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.6560 - accuracy: 0.7731 - precision_4: 0.8134 - recall_4: 0.7041 - auc_4: 0.9270 - f1_score: 0.6711 - val_loss: 0.6462 - val_accuracy: 0.7834 - val_precision_4: 0.8215 - val_recall_4: 0.7310 - val_auc_4: 0.9307 - val_f1_score: 0.7042
# Epoch 6/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.6338 - accuracy: 0.7979 - precision_4: 0.8184 - recall_4: 0.7542 - auc_4: 0.9350 - f1_score: 0.7189 - val_loss: 0.6225 - val_accuracy: 0.7888 - val_precision_4: 0.8058 - val_recall_4: 0.7491 - val_auc_4: 0.9380 - val_f1_score: 0.7077
# Epoch 7/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.6220 - accuracy: 0.7921 - precision_4: 0.8124 - recall_4: 0.7600 - auc_4: 0.9380 - f1_score: 0.7166 - val_loss: 0.6797 - val_accuracy: 0.7166 - val_precision_4: 0.7520 - val_recall_4: 0.6895 - val_auc_4: 0.9201 - val_f1_score: 0.5773
# Epoch 8/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.6156 - accuracy: 0.8033 - precision_4: 0.8293 - recall_4: 0.7605 - auc_4: 0.9412 - f1_score: 0.7281 - val_loss: 0.6231 - val_accuracy: 0.7762 - val_precision_4: 0.8130 - val_recall_4: 0.7455 - val_auc_4: 0.9375 - val_f1_score: 0.7031
# Epoch 9/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0
100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.4993 - accuracy: 0.8818 - precision_4: 0.8955 - recall_4: 0.8696 - auc_4: 0.9728 - f1_score: 0.8512 - val_loss: 0.6779 - val_accuracy: 0.7744 - val_precision_4: 0.7909 - val_recall_4: 0.7238 - val_auc_4: 0.9301 - val_f1_score: 0.6697
# Epoch 79/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.5028 - accuracy: 0.8832 - precision_4: 0.8936 - recall_4: 0.8710 - auc_4: 0.9726 - f1_score: 0.8519 - val_loss: 0.7246 - val_accuracy: 0.7581 - val_precision_4: 0.7890 - val_recall_4: 0.7220 - val_auc_4: 0.9232 - val_f1_score: 0.6642
# Epoch 80/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.4993 - accuracy: 0.8890 - precision_4: 0.9034 - recall_4: 0.8687 - auc_4: 0.9735 - f1_score: 0.8561 - val_loss: 0.6354 - val_accuracy: 0.7996 - val_precision_4: 0.8176 - val_recall_4: 0.7365 - val_auc_4: 0.9385 - val_f1_score: 0.6977
# Epoch 81/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.5128 - accuracy: 0.8764 - precision_4: 0.8882 - recall_4: 0.8633 - auc_4: 0.9694 - f1_score: 0.8432 - val_loss: 0.7299 - val_accuracy: 0.7383 - val_precision_4: 0.7567 - val_recall_4: 0.7130 - val_auc_4: 0.9145 - val_f1_score: 0.6486
# Epoch 82/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.5020 - accuracy: 0.8863 - precision_4: 0.8974 - recall_4: 0.8719 - auc_4: 0.9723 - f1_score: 0.8544 - val_loss: 0.5851 - val_accuracy: 0.8430 - val_precision_4: 0.8566 - val_recall_4: 0.7978 - val_auc_4: 0.9542 - val_f1_score: 0.7729
# Epoch 83/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.4953 - accuracy: 0.8890 - precision_4: 0.9021 - recall_4: 0.8773 - auc_4: 0.9743 - f1_score: 0.8616 - val_loss: 0.6252 - val_accuracy: 0.7924 - val_precision_4: 0.8311 - val_recall_4: 0.7726 - val_auc_4: 0.9430 - val_f1_score: 0.7395
# Epoch 84/100
# 70/70 [==============================] - 29s 419ms/step - loss: 0.4879 - accuracy: 0.8917 - precision_4: 0.9027 - recall_4: 0.8787 - auc_4: 0.9769 - f1_score: 0.8624 - val_loss: 0.6215 - val_accuracy: 0.7906 - val_precision_4: 0.8127 - val_recall_4: 0.7365 - val_auc_4: 0.9431 - val_f1_score: 0.6970
# Epoch 85/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.4942 - accuracy: 0.8908 - precision_4: 0.9023 - recall_4: 0.8751 - auc_4: 0.9749 - f1_score: 0.8596 - val_loss: 0.6222 - val_accuracy: 0.8105 - val_precision_4: 0.8440 - val_recall_4: 0.7617 - val_auc_4: 0.9428 - val_f1_score: 0.7346
# Epoch 86/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.4888 - accuracy: 0.8985 - precision_4: 0.9097 - recall_4: 0.8863 - auc_4: 0.9763 - f1_score: 0.8718 - val_loss: 0.7073 - val_accuracy: 0.7563 - val_precision_4: 0.7682 - val_recall_4: 0.7238 - val_auc_4: 0.9217 - val_f1_score: 0.6537
# Epoch 87/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.
100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.4787 - accuracy: 0.8999 - precision_4: 0.9085 - recall_4: 0.8872 - auc_4: 0.9783 - f1_score: 0.8720 - val_loss: 0.6626 - val_accuracy: 0.7708 - val_precision_4: 0.7856 - val_recall_4: 0.7473 - val_auc_4: 0.9328 - val_f1_score: 0.6939
# Epoch 98/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.4750 - accuracy: 0.8981 - precision_4: 0.9135 - recall_4: 0.8863 - auc_4: 0.9787 - f1_score: 0.8736 - val_loss: 0.7056 - val_accuracy: 0.7798 - val_precision_4: 0.7906 - val_recall_4: 0.7563 - val_auc_4: 0.9252 - val_f1_score: 0.7052
# Epoch 99/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.4769 - accuracy: 0.9008 - precision_4: 0.9095 - recall_4: 0.8886 - auc_4: 0.9782 - f1_score: 0.8739 - val_loss: 0.7132 - val_accuracy: 0.7708 - val_precision_4: 0.7882 - val_recall_4: 0.7455 - val_auc_4: 0.9245 - val_f1_score: 0.6859
# Epoch 100/100
# 70/70 [==============================] - 29s 420ms/step - loss: 0.4807 - accuracy: 0.8972 - precision_4: 0.9044 - recall_4: 0.8872 - auc_4: 0.9779 - f1_score: 0.8702 - val_loss: 0.6538 - val_accuracy: 0.8105 - val_precision_4: 0.8304 - val_recall_4: 0.7780 - val_auc_4: 0.9336 - val_f1_score: 0.7362

# %% [markdown]
# # ❤ Let's visualize the training progress of the model.

# %%
plot_training_curves(history, 'Affine (MS-Trust for Myelitis Classification: TE=2, SE=1, Conv=2)')

# %%
plot_training_curves(history, 'Affine (MS-Trust for Myelitis Classification: TE=2, SE=2, Conv=2)')

# %%
plot_training_curves(history, 'Affine (MS-Trust for Myelitis Classification: TE=3, SE=2, Conv=2)')

# %% [markdown]
# ---
#
# # ⏰ Flush memory varibales before using the next transfomer

# %%
del history
del model
del optimizer

# %% [markdown]
# ---
#
#
# # ✅ MixUp
# Use: train_ds_cmu_A, validation_ds_A

# %% [markdown]
# # 🈺 Ablation study: #2 Hyperparameters

# %%
#MS-Trust TE=1, SE=1, Conv=2
transformer_layers = 1
squeeze_excite_layers = 1
conv_layers = 2

# %%
#MS-Trust TE=2, SE=1, Conv=2
transformer_layers = 2
squeeze_excite_layers = 1
conv_layers = 2

# %%
#MS-Trust TE=3, SE=1, Conv=2
transformer_layers = 3
squeeze_excite_layers = 1
conv_layers = 2

# %%
#MS-Trust TE=2, SE=2, Conv=2
transformer_layers = 2
squeeze_excite_layers = 2
conv_layers = 2

# %%
#MS-Trust TE=3, SE=2, Conv=2
transformer_layers = 3
squeeze_excite_layers = 2
conv_layers = 2

# %% [markdown]
# # ⛓ The CCT tokenizer
#
# The first recipe introduced by the CCT authors is the tokenizer for processing the images. In a standard ViT, images are organized into uniform non-overlapping patches. This eliminates the boundary-level information present in between different patches. This is important for a neural network to effectively exploit the locality information. The figure below presents an illustration of how images are organized into patches.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We already know that convolutions are quite good at exploiting locality information. So, based on this, the authors introduce an all-convolution mini-network to produce image patches.

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super().__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %% [markdown]
# # ⛓ The final CCT model

# %%
def create_cct_model(
    image_size=IMG_SIZE,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):
    inputs = layers.Input(input_shape)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(inputs)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)

        # MLP.
        x3 = mlp2(x3, hidden_units=transformer_units, dropout_rate=0.1)

        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply SqueezeExcite
    if squeeze_excite_layers == 2:
      encoded_patches = mlp2(encoded_patches, hidden_units=transformer_units, dropout_rate=0.1)

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES , activation="softmax")(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
model = create_cct_model()

# %%
#Re-Run
optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)

model.compile(
    optimizer=optimizer,
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Precision(),
        keras.metrics.Recall(),
        keras.metrics.AUC(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', threshold=0.5),
        ],
    )
history = model.fit(train_ds_cmu_A,
                    validation_data=validation_ds_A,
                    batch_size=BATCH_SIZE,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/
100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4811 - accuracy: 0.9215 - precision_9: 0.9703 - recall_9: 0.6104 - auc_9: 0.8598 - f1_score: 0.8768 - val_loss: 0.8471 - val_accuracy: 0.7617 - val_precision_9: 0.7628 - val_recall_9: 0.7545 - val_auc_9: 0.8884 - val_f1_score: 0.6889
# Epoch 72/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4699 - accuracy: 0.9396 - precision_9: 0.9814 - recall_9: 0.6140 - auc_9: 0.8708 - f1_score: 0.8918 - val_loss: 0.8351 - val_accuracy: 0.7708 - val_precision_9: 0.7743 - val_recall_9: 0.7617 - val_auc_9: 0.8936 - val_f1_score: 0.6995
# Epoch 73/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4552 - accuracy: 0.9436 - precision_9: 0.9875 - recall_9: 0.6215 - auc_9: 0.8756 - f1_score: 0.9039 - val_loss: 0.8471 - val_accuracy: 0.7635 - val_precision_9: 0.7688 - val_recall_9: 0.7563 - val_auc_9: 0.8987 - val_f1_score: 0.6891
# Epoch 74/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4839 - accuracy: 0.9373 - precision_9: 0.9749 - recall_9: 0.6107 - auc_9: 0.8609 - f1_score: 0.8834 - val_loss: 0.7887 - val_accuracy: 0.7870 - val_precision_9: 0.7985 - val_recall_9: 0.7798 - val_auc_9: 0.8974 - val_f1_score: 0.7260
# Epoch 75/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4743 - accuracy: 0.9323 - precision_9: 0.9786 - recall_9: 0.6100 - auc_9: 0.8703 - f1_score: 0.8862 - val_loss: 0.8494 - val_accuracy: 0.7563 - val_precision_9: 0.7629 - val_recall_9: 0.7491 - val_auc_9: 0.8805 - val_f1_score: 0.6891
# Epoch 76/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4565 - accuracy: 0.9535 - precision_9: 0.9852 - recall_9: 0.6158 - auc_9: 0.8649 - f1_score: 0.9034 - val_loss: 0.8747 - val_accuracy: 0.7545 - val_precision_9: 0.7629 - val_recall_9: 0.7491 - val_auc_9: 0.9050 - val_f1_score: 0.6860
# Epoch 77/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4389 - accuracy: 0.9626 - precision_9: 0.9867 - recall_9: 0.6296 - auc_9: 0.8724 - f1_score: 0.9137 - val_loss: 0.8841 - val_accuracy: 0.7527 - val_precision_9: 0.7601 - val_recall_9: 0.7491 - val_auc_9: 0.8988 - val_f1_score: 0.6903
# Epoch 78/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4728 - accuracy: 0.9382 - precision_9: 0.9787 - recall_9: 0.6132 - auc_9: 0.8640 - f1_score: 0.8935 - val_loss: 0.8326 - val_accuracy: 0.7491 - val_precision_9: 0.7587 - val_recall_9: 0.7437 - val_auc_9: 0.9021 - val_f1_score: 0.6804
# Epoch 79/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4613 - accuracy: 0.9441 - precision_9: 0.9810 - recall_9: 0.6202 - auc_9: 0.8654 - f1_score: 0.9014 - val_loss: 0.8620 - val_accuracy: 0.7527 - val_precision_9: 0.7541 - val_recall_9: 0.7419 - val_auc_9: 0.8882 - val_f1_score: 0.6765
# Epoch 80/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.4744 - accuracy: 0.9355 - precision_9: 0.9777 - recall_9: 0.6134 - auc_9: 0.8657 - f1_score: 0.8851 - val_loss: 0.7982 - val_accuracy: 0.7599 - val_precision_9: 0.7661 - val_recall_9: 0.7509 - val_auc_9: 0.9272 - val_f1_score: 0.6897
# Epoch 81/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.
100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.4449 - accuracy: 0.9576 - precision_9: 0.9886 - recall_9: 0.6300 - auc_9: 0.8777 - f1_score: 0.9105 - val_loss: 0.8470 - val_accuracy: 0.7563 - val_precision_9: 0.7586 - val_recall_9: 0.7545 - val_auc_9: 0.9129 - val_f1_score: 0.6885

# %% [markdown]
# # ❤ Let's visualize the training progress of the model.

# %%
plot_training_curves(history, 'MixUp (MS-Trust TE=1, SE=1, Conv=2)')

# %%
plot_training_curves(history, 'MixUp (MS-Trust TE=2, SE=1, Conv=2)')

# %%
plot_training_curves(history, 'MixUp (MS-Trust TE=3, SE=1, Conv=2)')

# %%
plot_training_curves(history, 'MixUp (MS-Trust TE=2, SE=2, Conv=2)')

# %%
plot_training_curves(history, 'MixUp (MS-Trust TE=3, SE=2, Conv=2)')

# %% [markdown]
# ---
#
# # ⏰ Flush memory varibales before using the next transfomer

# %%
del history
del model
del optimizer

# %% [markdown]
# ---
#
#
# # ✅ CutMix
# Use: train_ds_cmu_B, validation_ds_B

# %% [markdown]
# # 🈺 Ablation study: #3 Hyperparameters

# %%
#MS-Trust TE=1, SE=1, Conv=2
transformer_layers = 1
squeeze_excite_layers = 1
conv_layers = 2

# %%
#MS-Trust TE=2, SE=1, Conv=2
transformer_layers = 2
squeeze_excite_layers = 1
conv_layers = 2

# %%
#MS-Trust TE=3, SE=1, Conv=2
transformer_layers = 3
squeeze_excite_layers = 1
conv_layers = 2

# %%
#MS-Trust TE=2, SE=2, Conv=2
transformer_layers = 2
squeeze_excite_layers = 2
conv_layers = 2

# %%
#MS-Trust TE=3, SE=2, Conv=2
transformer_layers = 3
squeeze_excite_layers = 2
conv_layers = 2

# %% [markdown]
# # ⛓ The CCT tokenizer
#
# The first recipe introduced by the CCT authors is the tokenizer for processing the images. In a standard ViT, images are organized into uniform non-overlapping patches. This eliminates the boundary-level information present in between different patches. This is important for a neural network to effectively exploit the locality information. The figure below presents an illustration of how images are organized into patches.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We already know that convolutions are quite good at exploiting locality information. So, based on this, the authors introduce an all-convolution mini-network to produce image patches.

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super().__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %% [markdown]
# # ⛓ The final CCT model

# %%
def create_cct_model(
    image_size=IMG_SIZE,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):
    inputs = layers.Input(input_shape)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(inputs)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)

        # MLP.
        x3 = mlp2(x3, hidden_units=transformer_units, dropout_rate=0.1)

        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply SqueezeExcite
    if squeeze_excite_layers == 2:
      encoded_patches = mlp2(encoded_patches, hidden_units=transformer_units, dropout_rate=0.1)

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES , activation="softmax")(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model
model = create_cct_model()

# %%
#Re-Run
optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)

model.compile(
    optimizer=optimizer,
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Precision(),
        keras.metrics.Recall(),
        keras.metrics.AUC(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', threshold=0.5),
        ],
    )
history = model.fit(train_ds_cmu_B,
                    validation_data=validation_ds_B,
                    batch_size=BATCH_SIZE,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 70/70 [==============================] - 26s 300ms/step - loss: 0.9417 - accuracy: 0.6283 - precision_16: 0.8584 - recall_16: 0.3194 - auc_16: 0.7355 - f1_score: 0.3623 - val_loss: 0.7003 - val_accuracy: 0.7744 - val_precision_16: 0.7933 - val_recall_16: 0.7274 - val_auc_16: 0.9114 - val_f1_score: 0.6909
# Epoch 2/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.8049 - accuracy: 0.7028 - precision_16: 0.8930 - recall_16: 0.4316 - auc_16: 0.8154 - f1_score: 0.5356 - val_loss: 0.6776 - val_accuracy: 0.7310 - val_precision_16: 0.7407 - val_recall_16: 0.7220 - val_auc_16: 0.9254 - val_f1_score: 0.5408
# Epoch 3/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0
100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6894 - accuracy: 0.7997 - precision_16: 0.9241 - recall_16: 0.5252 - auc_16: 0.8661 - f1_score: 0.6943 - val_loss: 0.6637 - val_accuracy: 0.7545 - val_precision_16: 0.7654 - val_recall_16: 0.7419 - val_auc_16: 0.9340 - val_f1_score: 0.6762
# Epoch 24/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6784 - accuracy: 0.8069 - precision_16: 0.9453 - recall_16: 0.5224 - auc_16: 0.8776 - f1_score: 0.7005 - val_loss: 0.6434 - val_accuracy: 0.7581 - val_precision_16: 0.7734 - val_recall_16: 0.7455 - val_auc_16: 0.9395 - val_f1_score: 0.6862
# Epoch 25/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6781 - accuracy: 0.7984 - precision_16: 0.9346 - recall_16: 0.5253 - auc_16: 0.8732 - f1_score: 0.7028 - val_loss: 0.6524 - val_accuracy: 0.7671 - val_precision_16: 0.7834 - val_recall_16: 0.7509 - val_auc_16: 0.9370 - val_f1_score: 0.6978
# Epoch 26/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6949 - accuracy: 0.8051 - precision_16: 0.9323 - recall_16: 0.5217 - auc_16: 0.8688 - f1_score: 0.6948 - val_loss: 0.6395 - val_accuracy: 0.7708 - val_precision_16: 0.7763 - val_recall_16: 0.7581 - val_auc_16: 0.9392 - val_f1_score: 0.7011
# Epoch 27/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6809 - accuracy: 0.8042 - precision_16: 0.9391 - recall_16: 0.5199 - auc_16: 0.8742 - f1_score: 0.7026 - val_loss: 0.6450 - val_accuracy: 0.7437 - val_precision_16: 0.7667 - val_recall_16: 0.7238 - val_auc_16: 0.9352 - val_f1_score: 0.6662
# Epoch 28/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6804 - accuracy: 0.8029 - precision_16: 0.9292 - recall_16: 0.5233 - auc_16: 0.8751 - f1_score: 0.6983 - val_loss: 0.6320 - val_accuracy: 0.7690 - val_precision_16: 0.7804 - val_recall_16: 0.7635 - val_auc_16: 0.9419 - val_f1_score: 0.7075
# Epoch 29/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6796 - accuracy: 0.8092 - precision_16: 0.9423 - recall_16: 0.5231 - auc_16: 0.8778 - f1_score: 0.7042 - val_loss: 0.6820 - val_accuracy: 0.7888 - val_precision_16: 0.7996 - val_recall_16: 0.7563 - val_auc_16: 0.9307 - val_f1_score: 0.6926
# Epoch 30/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6775 - accuracy: 0.8069 - precision_16: 0.9350 - recall_16: 0.5289 - auc_16: 0.8780 - f1_score: 0.7006 - val_loss: 0.6388 - val_accuracy: 0.7635 - val_precision_16: 0.7841 - val_recall_16: 0.7473 - val_auc_16: 0.9386 - val_f1_score: 0.6927
# Epoch 31/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6943 - accuracy: 0.7961 - precision_16: 0.9348 - recall_16: 0.5170 - auc_16: 0.8696 - f1_score: 0.6898 - val_loss: 0.6312 - val_accuracy: 0.7780 - val_precision_16: 0.7892 - val_recall_16: 0.7365 - val_auc_16: 0.9377 - val_f1_score: 0.6879
# Epoch 32/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6767 - accuracy: 0.8115 - precision_16: 0.9420 - recall_16: 0.5196 - auc_16: 0.8761 - f1_score: 0.7019 - val_loss: 0.6219 - val_accuracy: 0.7671 - val_precision_16: 0.8008 - val_recall_16: 0.7329 - val_auc_16: 0.9401 - val_f1_score: 0.6850
# Epoch 33/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.
100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6763 - accuracy: 0.8038 - precision_16: 0.9390 - recall_16: 0.5307 - auc_16: 0.8759 - f1_score: 0.7138 - val_loss: 0.6317 - val_accuracy: 0.7671 - val_precision_16: 0.7792 - val_recall_16: 0.7455 - val_auc_16: 0.9388 - val_f1_score: 0.6911
# Epoch 54/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6582 - accuracy: 0.8155 - precision_16: 0.9501 - recall_16: 0.5295 - auc_16: 0.8875 - f1_score: 0.7250 - val_loss: 0.6953 - val_accuracy: 0.7563 - val_precision_16: 0.7692 - val_recall_16: 0.7401 - val_auc_16: 0.9283 - val_f1_score: 0.6753
# Epoch 55/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6521 - accuracy: 0.8191 - precision_16: 0.9386 - recall_16: 0.5440 - auc_16: 0.8804 - f1_score: 0.7252 - val_loss: 0.6015 - val_accuracy: 0.7960 - val_precision_16: 0.8333 - val_recall_16: 0.7671 - val_auc_16: 0.9498 - val_f1_score: 0.7366
# Epoch 56/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6384 - accuracy: 0.8372 - precision_16: 0.9561 - recall_16: 0.5496 - auc_16: 0.8919 - f1_score: 0.7404 - val_loss: 0.7294 - val_accuracy: 0.7708 - val_precision_16: 0.7888 - val_recall_16: 0.7617 - val_auc_16: 0.9260 - val_f1_score: 0.6925
# Epoch 57/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6587 - accuracy: 0.8178 - precision_16: 0.9515 - recall_16: 0.5450 - auc_16: 0.8905 - f1_score: 0.7305 - val_loss: 0.6815 - val_accuracy: 0.7671 - val_precision_16: 0.7857 - val_recall_16: 0.7545 - val_auc_16: 0.9339 - val_f1_score: 0.7014
# Epoch 58/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6510 - accuracy: 0.8223 - precision_16: 0.9505 - recall_16: 0.5372 - auc_16: 0.8858 - f1_score: 0.7295 - val_loss: 0.6873 - val_accuracy: 0.7563 - val_precision_16: 0.7596 - val_recall_16: 0.7473 - val_auc_16: 0.9357 - val_f1_score: 0.6839
# Epoch 59/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6453 - accuracy: 0.8327 - precision_16: 0.9518 - recall_16: 0.5453 - auc_16: 0.8862 - f1_score: 0.7337 - val_loss: 0.6828 - val_accuracy: 0.7563 - val_precision_16: 0.7685 - val_recall_16: 0.7491 - val_auc_16: 0.9303 - val_f1_score: 0.6892
# Epoch 60/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6506 - accuracy: 0.8277 - precision_16: 0.9508 - recall_16: 0.5391 - auc_16: 0.8924 - f1_score: 0.7260 - val_loss: 0.6527 - val_accuracy: 0.7834 - val_precision_16: 0.8000 - val_recall_16: 0.7726 - val_auc_16: 0.9391 - val_f1_score: 0.7247
# Epoch 61/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6375 - accuracy: 0.8345 - precision_16: 0.9567 - recall_16: 0.5465 - auc_16: 0.8867 - f1_score: 0.7405 - val_loss: 0.6253 - val_accuracy: 0.7690 - val_precision_16: 0.8063 - val_recall_16: 0.7365 - val_auc_16: 0.9433 - val_f1_score: 0.6914
# Epoch 62/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6527 - accuracy: 0.8272 - precision_16: 0.9590 - recall_16: 0.5399 - auc_16: 0.8910 - f1_score: 0.7296 - val_loss: 0.6815 - val_accuracy: 0.7726 - val_precision_16: 0.7782 - val_recall_16: 0.7473 - val_auc_16: 0.9342 - val_f1_score: 0.6862
# Epoch 63/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6349 - accuracy: 0.8263 - precision_16: 0.9556 - recall_16: 0.5510 - auc_16: 0.8883 - f1_score: 0.7461 - val_loss: 0.6609 - val_accuracy: 0.7744 - val_precision_16: 0.7887 - val_recall_16: 0.7545 - val_auc_16: 0.9391 - val_f1_score: 0.7007
# Epoch 64/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6438 - accuracy: 0.8218 - precision_16: 0.9522 - recall_16: 0.5511 - auc_16: 0.8908 - f1_score: 0.7343 - val_loss: 0.6980 - val_accuracy: 0.7635 - val_precision_16: 0.7824 - val_recall_16: 0.7527 - val_auc_16: 0.9316 - val_f1_score: 0.6966
# Epoch 65/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6406 - accuracy: 0.8322 - precision_16: 0.9488 - recall_16: 0.5302 - auc_16: 0.8876 - f1_score: 0.7324 - val_loss: 0.6731 - val_accuracy: 0.7726 - val_precision_16: 0.8038 - val_recall_16: 0.7545 - val_auc_16: 0.9383 - val_f1_score: 0.7028
# Epoch 66/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6379 - accuracy: 0.8381 - precision_16: 0.9536 - recall_16: 0.5501 - auc_16: 0.8901 - f1_score: 0.7400 - val_loss: 0.7033 - val_accuracy: 0.7599 - val_precision_16: 0.7805 - val_recall_16: 0.7383 - val_auc_16: 0.9278 - val_f1_score: 0.6797
# Epoch 67/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6565 - accuracy: 0.8223 - precision_16: 0.9460 - recall_16: 0.5338 - auc_16: 0.8808 - f1_score: 0.7244 - val_loss: 0.7158 - val_accuracy: 0.7617 - val_precision_16: 0.7713 - val_recall_16: 0.7365 - val_auc_16: 0.9332 - val_f1_score: 0.6608
# Epoch 68/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6459 - accuracy: 0.8318 - precision_16: 0.9526 - recall_16: 0.5425 - auc_16: 0.8899 - f1_score: 0.7293 - val_loss: 0.7181 - val_accuracy: 0.7671 - val_precision_16: 0.7924 - val_recall_16: 0.7509 - val_auc_16: 0.9268 - val_f1_score: 0.6876
# Epoch 69/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6318 - accuracy: 0.8394 - precision_16: 0.9566 - recall_16: 0.5522 - auc_16: 0.8945 - f1_score: 0.7477 - val_loss: 0.6397 - val_accuracy: 0.7978 - val_precision_16: 0.8147 - val_recall_16: 0.7780 - val_auc_16: 0.9449 - val_f1_score: 0.7362
# Epoch 70/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6472 - accuracy: 0.8376 - precision_16: 0.9506 - recall_16: 0.5401 - auc_16: 0.8836 - f1_score: 0.7402 - val_loss: 0.6392 - val_accuracy: 0.7798 - val_precision_16: 0.7932 - val_recall_16: 0.7617 - val_auc_16: 0.9424 - val_f1_score: 0.7124
# Epoch 71/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6385 - accuracy: 0.8354 - precision_16: 0.9574 - recall_16: 0.5430 - auc_16: 0.8912 - f1_score: 0.7433 - val_loss: 0.6831 - val_accuracy: 0.7798 - val_precision_16: 0.8008 - val_recall_16: 0.7690 - val_auc_16: 0.9377 - val_f1_score: 0.7200
# Epoch 72/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6351 - accuracy: 0.8322 - precision_16: 0.9557 - recall_16: 0.5527 - auc_16: 0.8895 - f1_score: 0.7510 - val_loss: 0.6469 - val_accuracy: 0.7906 - val_precision_16: 0.8022 - val_recall_16: 0.7834 - val_auc_16: 0.9452 - val_f1_score: 0.7323
# Epoch 73/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6440 - accuracy: 0.8241 - precision_16: 0.9494 - recall_16: 0.5420 - auc_16: 0.8890 - f1_score: 0.7381 - val_loss: 0.6173 - val_accuracy: 0.8032 - val_precision_16: 0.8170 - val_recall_16: 0.7816 - val_auc_16: 0.9475 - val_f1_score: 0.7406
# Epoch 74/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6483 - accuracy: 0.8209 - precision_16: 0.9557 - recall_16: 0.5379 - auc_16: 0.8943 - f1_score: 0.7305 - val_loss: 0.6355 - val_accuracy: 0.7744 - val_precision_16: 0.8058 - val_recall_16: 0.7563 - val_auc_16: 0.9433 - val_f1_score: 0.7096
# Epoch 75/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6320 - accuracy: 0.8412 - precision_16: 0.9595 - recall_16: 0.5547 - auc_16: 0.8942 - f1_score: 0.7510 - val_loss: 0.6023 - val_accuracy: 0.7978 - val_precision_16: 0.8086 - val_recall_16: 0.7780 - val_auc_16: 0.9499 - val_f1_score: 0.7339
# Epoch 76/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6246 - accuracy: 0.8403 - precision_16: 0.9626 - recall_16: 0.5662 - auc_16: 0.8975 - f1_score: 0.7625 - val_loss: 0.7061 - val_accuracy: 0.7780 - val_precision_16: 0.7970 - val_recall_16: 0.7581 - val_auc_16: 0.9289 - val_f1_score: 0.7051
# Epoch 77/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6247 - accuracy: 0.8421 - precision_16: 0.9623 - recall_16: 0.5595 - auc_16: 0.8941 - f1_score: 0.7557 - val_loss: 0.6298 - val_accuracy: 0.7978 - val_precision_16: 0.8093 - val_recall_16: 0.7816 - val_auc_16: 0.9464 - val_f1_score: 0.7366
# Epoch 78/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6310 - accuracy: 0.8421 - precision_16: 0.9633 - recall_16: 0.5450 - auc_16: 0.8935 - f1_score: 0.7531 - val_loss: 0.5849 - val_accuracy: 0.8231 - val_precision_16: 0.8369 - val_recall_16: 0.7870 - val_auc_16: 0.9534 - val_f1_score: 0.7549
# Epoch 79/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6326 - accuracy: 0.8453 - precision_16: 0.9576 - recall_16: 0.5500 - auc_16: 0.8935 - f1_score: 0.7526 - val_loss: 0.6380 - val_accuracy: 0.7852 - val_precision_16: 0.8004 - val_recall_16: 0.7671 - val_auc_16: 0.9422 - val_f1_score: 0.7205
# Epoch 80/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6357 - accuracy: 0.8349 - precision_16: 0.9600 - recall_16: 0.5501 - auc_16: 0.8900 - f1_score: 0.7440 - val_loss: 0.6139 - val_accuracy: 0.7870 - val_precision_16: 0.7928 - val_recall_16: 0.7599 - val_auc_16: 0.9445 - val_f1_score: 0.7092
# Epoch 81/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6223 - accuracy: 0.8475 - precision_16: 0.9608 - recall_16: 0.5654 - auc_16: 0.9001 - f1_score: 0.7624 - val_loss: 0.6917 - val_accuracy: 0.7780 - val_precision_16: 0.7907 - val_recall_16: 0.7635 - val_auc_16: 0.9294 - val_f1_score: 0.7120
# Epoch 82/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6317 - accuracy: 0.8300 - precision_16: 0.9546 - recall_16: 0.5469 - auc_16: 0.8953 - f1_score: 0.7449 - val_loss: 0.6675 - val_accuracy: 0.7780 - val_precision_16: 0.7892 - val_recall_16: 0.7635 - val_auc_16: 0.9383 - val_f1_score: 0.7124
# Epoch 83/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6242 - accuracy: 0.8385 - precision_16: 0.9618 - recall_16: 0.5567 - auc_16: 0.8967 - f1_score: 0.7572 - val_loss: 0.6884 - val_accuracy: 0.7834 - val_precision_16: 0.8064 - val_recall_16: 0.7744 - val_auc_16: 0.9335 - val_f1_score: 0.7251
# Epoch 84/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6202 - accuracy: 0.8566 - precision_16: 0.9612 - recall_16: 0.5639 - auc_16: 0.8955 - f1_score: 0.7650 - val_loss: 0.7826 - val_accuracy: 0.7635 - val_precision_16: 0.7718 - val_recall_16: 0.7509 - val_auc_16: 0.9224 - val_f1_score: 0.6699
# Epoch 85/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6335 - accuracy: 0.8412 - precision_16: 0.9608 - recall_16: 0.5495 - auc_16: 0.8934 - f1_score: 0.7511 - val_loss: 0.7228 - val_accuracy: 0.7780 - val_precision_16: 0.8085 - val_recall_16: 0.7545 - val_auc_16: 0.9275 - val_f1_score: 0.7104
# Epoch 86/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6204 - accuracy: 0.8521 - precision_16: 0.9665 - recall_16: 0.5638 - auc_16: 0.8985 - f1_score: 0.7655 - val_loss: 0.6887 - val_accuracy: 0.8014 - val_precision_16: 0.8105 - val_recall_16: 0.7798 - val_auc_16: 0.9426 - val_f1_score: 0.7309
# Epoch 87/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6056 - accuracy: 0.8602 - precision_16: 0.9688 - recall_16: 0.5701 - auc_16: 0.9075 - f1_score: 0.7718 - val_loss: 0.6621 - val_accuracy: 0.7888 - val_precision_16: 0.8022 - val_recall_16: 0.7762 - val_auc_16: 0.9409 - val_f1_score: 0.7284
# Epoch 88/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6167 - accuracy: 0.8552 - precision_16: 0.9702 - recall_16: 0.5641 - auc_16: 0.8999 - f1_score: 0.7670 - val_loss: 0.6619 - val_accuracy: 0.8032 - val_precision_16: 0.8163 - val_recall_16: 0.7780 - val_auc_16: 0.9396 - val_f1_score: 0.7345
# Epoch 89/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6047 - accuracy: 0.8597 - precision_16: 0.9706 - recall_16: 0.5679 - auc_16: 0.9007 - f1_score: 0.7741 - val_loss: 0.6205 - val_accuracy: 0.8159 - val_precision_16: 0.8255 - val_recall_16: 0.7942 - val_auc_16: 0.9490 - val_f1_score: 0.7560
# Epoch 90/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6144 - accuracy: 0.8588 - precision_16: 0.9665 - recall_16: 0.5604 - auc_16: 0.8957 - f1_score: 0.7721 - val_loss: 0.6657 - val_accuracy: 0.7888 - val_precision_16: 0.7922 - val_recall_16: 0.7708 - val_auc_16: 0.9392 - val_f1_score: 0.7195
# Epoch 91/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6166 - accuracy: 0.8588 - precision_16: 0.9706 - recall_16: 0.5612 - auc_16: 0.8980 - f1_score: 0.7692 - val_loss: 0.7153 - val_accuracy: 0.7744 - val_precision_16: 0.7768 - val_recall_16: 0.7599 - val_auc_16: 0.9305 - val_f1_score: 0.6963
# Epoch 92/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6102 - accuracy: 0.8566 - precision_16: 0.9675 - recall_16: 0.5635 - auc_16: 0.9031 - f1_score: 0.7701 - val_loss: 0.7146 - val_accuracy: 0.7816 - val_precision_16: 0.7944 - val_recall_16: 0.7744 - val_auc_16: 0.9283 - val_f1_score: 0.7183
# Epoch 93/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6087 - accuracy: 0.8570 - precision_16: 0.9709 - recall_16: 0.5711 - auc_16: 0.9019 - f1_score: 0.7744 - val_loss: 0.6810 - val_accuracy: 0.7924 - val_precision_16: 0.8072 - val_recall_16: 0.7708 - val_auc_16: 0.9348 - val_f1_score: 0.7260
# Epoch 94/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.6018 - accuracy: 0.8692 - precision_16: 0.9744 - recall_16: 0.5755 - auc_16: 0.9051 - f1_score: 0.7755 - val_loss: 0.6408 - val_accuracy: 0.8051 - val_precision_16: 0.8163 - val_recall_16: 0.7942 - val_auc_16: 0.9465 - val_f1_score: 0.7521
# Epoch 95/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6093 - accuracy: 0.8534 - precision_16: 0.9709 - recall_16: 0.5722 - auc_16: 0.9036 - f1_score: 0.7786 - val_loss: 0.6714 - val_accuracy: 0.7960 - val_precision_16: 0.8007 - val_recall_16: 0.7834 - val_auc_16: 0.9394 - val_f1_score: 0.7340
# Epoch 96/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6030 - accuracy: 0.8724 - precision_16: 0.9698 - recall_16: 0.5784 - auc_16: 0.9066 - f1_score: 0.7835 - val_loss: 0.6338 - val_accuracy: 0.7996 - val_precision_16: 0.8234 - val_recall_16: 0.7744 - val_auc_16: 0.9455 - val_f1_score: 0.7354
# Epoch 97/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.5948 - accuracy: 0.8674 - precision_16: 0.9767 - recall_16: 0.5754 - auc_16: 0.9039 - f1_score: 0.7842 - val_loss: 0.6095 - val_accuracy: 0.8213 - val_precision_16: 0.8262 - val_recall_16: 0.8069 - val_auc_16: 0.9516 - val_f1_score: 0.7677
# Epoch 98/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.5975 - accuracy: 0.8701 - precision_16: 0.9712 - recall_16: 0.5758 - auc_16: 0.8993 - f1_score: 0.7845 - val_loss: 0.6539 - val_accuracy: 0.7960 - val_precision_16: 0.8056 - val_recall_16: 0.7780 - val_auc_16: 0.9439 - val_f1_score: 0.7311
# Epoch 99/100
# 70/70 [==============================] - 20s 287ms/step - loss: 0.6041 - accuracy: 0.8651 - precision_16: 0.9724 - recall_16: 0.5718 - auc_16: 0.8971 - f1_score: 0.7789 - val_loss: 0.6186 - val_accuracy: 0.8087 - val_precision_16: 0.8197 - val_recall_16: 0.7960 - val_auc_16: 0.9493 - val_f1_score: 0.7544
# Epoch 100/100
# 70/70 [==============================] - 20s 288ms/step - loss: 0.5954 - accuracy: 0.8647 - precision_16: 0.9707 - recall_16: 0.5737 - auc_16: 0.9086 - f1_score: 0.7825 - val_loss: 0.6934 - val_accuracy: 0.7996 - val_precision_16: 0.8066 - val_recall_16: 0.7906 - val_auc_16: 0.9398 - val_f1_score: 0.7367

# %% [markdown]
# # ❤ Let's visualize the training progress of the model.

# %%
plot_training_curves(history, 'CutMix (MS-Trust TE=1, SE=1, Conv=2)')

# %%
plot_training_curves(history, 'CutMix (MS-Trust TE=2, SE=1, Conv=2)')

# %%
plot_training_curves(history, 'CutMix (MS-Trust TE=3, SE=1, Conv=2)')

# %%
plot_training_curves(history, 'CutMix (MS-Trust TE=2, SE=2, Conv=2)')

# %%
plot_training_curves(history, 'CutMix (MS-Trust TE=3, SE=2, Conv=2)')

# %% [markdown]
# ---
#
# # ⏰ Flush memory varibales before using the next transfomer

# %%
del model
del optimizer
del history
