# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/MS_Trust/blob/main/_DualAtten_MS_Axial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 MS Classification: Transformer Model with Causal-Global Dual Attention

# %%
# !pip install -U -q tensorflow-addons
# !pip install nest_asyncio
# !pip install keras-cv tensorflow --upgrade

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory
import keras_cv

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import numpy as np
from google.colab import drive
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight

# Define the path to the MRI data directory
drive.mount('/content/drive', force_remount=True)

import nest_asyncio

# %% [markdown]
# # 🈺 Hyperparameters

# %%
######################
NUM_CLASSES = 2
######################
positional_emb = True
conv_layers = 2
projection_dim = 128
num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
transformer_layers = 2
stochastic_depth_rate = 0.1
learning_rate = 0.001
weight_decay = 0.0001
NUM_EPOCHS = 100
IMG_SIZE =64
BATCH_SIZE = 32
input_shape = (64, 64, 3)
np.random.seed(42)
tf.random.set_seed(42)
AUTO = tf.data.AUTOTUNE

# %%
def preprocess_image(path):
    image = tf.keras.utils.load_img(path)
    image = tf.image.central_crop(image, central_fraction=0.9)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = tf.image.convert_image_dtype(image, tf.float32) / 255.0
    return image

# %%
plt.imshow(preprocess_image(os.path.join("/content/drive/MyDrive/Multiple_Sclerosis_Dataset/Axial/Control_Axial/", "C-A (1).png" )))

# %%
def plot_training_curves(history, title):
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])
    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])
    epochs = range(len(history.history['loss']))
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='.')
    ax1.plot(epochs, val_loss, label='val_loss', marker='.')
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)
    ax1.set_title('Loss: '+title, fontsize=16)
    ax1.set_xlabel('Epochs', fontsize=14)
    ax1.legend()

    # Plot accuracy
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='.')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='.')
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)
    ax2.set_title('Accuracy: '+title, fontsize=16)
    ax2.set_xlabel('Epochs', fontsize=14)
    ax2.legend();

# %% [markdown]
# ---
# # 🧠 Axial

# %%
path = '/content/drive/MyDrive/Multiple_Sclerosis_Dataset/Axial/'
# train data
train_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(IMG_SIZE,IMG_SIZE),
    color_mode='rgb',
    #shuffle=True,
    seed=128,
    validation_split=0.2,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# validation data
val_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(IMG_SIZE,IMG_SIZE),
    color_mode='rgb',
    #shuffle=True,
    seed=128,
    validation_split=0.2,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 1652 files belonging to 2 classes.
# Using 1322 files for training.
# Found 1652 files belonging to 2 classes.
# Using 330 files for validation.

# %%
#label_mode='categorical',
train_ds_cat = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(IMG_SIZE,IMG_SIZE),
)
class_names = train_ds_cat.class_names
num_images_per_class = []
for label in class_names:
    dir_name = path + label
    num_images_per_class.append(len([name for name in os.listdir(dir_name)]))
# y_train=list of train labels wrt to given directory format
y_train=[]
for i in range(0, len(num_images_per_class)):
    y_train+=[i]*num_images_per_class[i]
classes = list()
for i in range(NUM_CLASSES): classes.append(i)
class_weights=compute_class_weight(class_weight="balanced",classes=classes, y=np.asarray(y_train))
class_weights_dict = {}
for i in range(len(class_weights)):
   class_weights_dict[i] = class_weights[i]
class_weights_dict
# Out:
# Found 1652 files belonging to 2 classes.
# {0: 0.8243512974051896, 1: 1.2707692307692309}

# %% [markdown]
# # 🅰 Data augmentation

# %%
def to_dict(image, label):
    image = tf.cast(image, tf.float32)
    label = tf.one_hot(label, NUM_CLASSES)
    return {"images": image, "labels": label}

def preprocess_for_model(inputs):
    images, labels = inputs["images"], inputs["labels"]
    images = tf.cast(images, tf.float32)
    return images, labels

mixup = keras_cv.layers.MixUp()
cutmix = keras_cv.layers.CutMix(alpha=0.02)

#No augmentation
train_ds_v = train_ds.map(to_dict)
train_ds_v = train_ds_v.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
train_ds_v = train_ds_v.prefetch(AUTOTUNE)
val_ds_v = val_ds.map(to_dict)
val_ds_v = val_ds_v.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
val_ds_v = val_ds_v.prefetch(AUTOTUNE) #Use this for fit

# %%
def aug_pipeline1(samples):
    samples = mixup(samples, training=True)
    return samples
def aug_pipeline2(samples):
    samples = cutmix(samples, training=True)
    return samples

#MixUp
mixup_ds = train_ds.shuffle(1000).map(to_dict)
mixup_ds = mixup_ds.map(aug_pipeline1)
mixup_ds = mixup_ds.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
mixup_ds = mixup_ds.prefetch(AUTOTUNE) #Use this for fit
#CutMix
cutmix_ds = train_ds.shuffle(1000).map(to_dict)
cutmix_ds = cutmix_ds.map(aug_pipeline2)
cutmix_ds = cutmix_ds.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
cutmix_ds = cutmix_ds.prefetch(AUTOTUNE) #Use this for fit

# %% [markdown]
# ---
#
#
# ## ⛓ The CCT tokenizer
#
# The first recipe introduced by the CCT authors is the tokenizer for processing the images. In a standard ViT, images are organized into uniform non-overlapping patches. This eliminates the boundary-level information present in between different patches. This is important for a neural network to effectively exploit the locality information. The figure below presents an illustration of how images are organized into patches.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We already know that convolutions are quite good at exploiting locality information. So, based on this, the authors introduce an all-convolution mini-network to produce image patches.

# %%
#https://keras.io/examples/vision/cct/
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super().__init__(**kwargs)
        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )
        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]
            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %% [markdown]
# ## Stochastic depth for regularization
#
# Stochastic depth is a regularization technique that randomly drops a set of layers. During inference, the layers are kept as they are. It is very much similar to Dropout but only that it operates on a block of layers rather than individual nodes present inside a layer. In CCT, stochastic depth is used just before the residual blocks of a Transformers encoder.

# %%
# Referred from: github.com:rwightman/pytorch-image-models.
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prop
    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (tf.shape(x).shape[0] - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %% [markdown]
# ## MLP for the Transformers encoder

# %%
class SqueezeExcite(layers.Layer):
    """Applies squeeze and excitation to input feature maps as seen in https://arxiv.org/abs/1709.01507.
    Args:         ratio: The ratio with which the feature map needs to be reduced in the reduction phase.
    Inputs:         Convolutional features.
    Outputs:        Attention modified feature maps.
    """
    def __init__(self, ratio, **kwargs):
        super().__init__(**kwargs)
        self.ratio = ratio
    def get_config(self):
        config = super().get_config()
        config.update({"ratio": self.ratio})
        return config
    def build(self, input_shape):
        filters = input_shape[-1]
        self.squeeze = layers.GlobalAveragePooling2D(keepdims=True)
        self.reduction = layers.Dense(
            units=filters // self.ratio, activation="relu", use_bias=False,
        )
        self.excite = layers.Dense(units=filters, activation="sigmoid", use_bias=False)
        self.multiply = layers.Multiply()
    def call(self, x):
        shortcut = x
        x = self.squeeze(x)
        x = self.reduction(x)
        x = self.excite(x)
        x = self.multiply([shortcut, x])
        return x
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        SqueezeExcite(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ## Attention layers

# %%
class BaseAttention(tf.keras.layers.Layer):
  """
  Base Attention layer class that contains a MultiHeadAttention, LayerNormalization and Add layer.
  """
  def __init__(self, **kwargs):
    super().__init__()
    self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
    self.layernorm = tf.keras.layers.LayerNormalization()
    self.add = tf.keras.layers.Add()

class CrossAttention(BaseAttention):
  """
  A class that implements cross-attention mechanism by inheriting from BaseAttention class.
  Cross-attention is used to process two different sequences and attends to the context sequence while processing the query sequence.
  """
  def call(self, x, context):
    """
    The call function that performs the cross-attention operation.
    Args:
        x: The query sequence tensor, shape=(batch_size, seq_len, embedding_dim)
        context: The context sequence tensor, shape=(batch_size, seq_len, embedding_dim)
    Returns:
        The attended output tensor, shape=(batch_size, seq_len, embedding_dim)
    """
    attn_output, attn_scores = self.mha(
        query=x,
        key=context,
        value=context,
        return_attention_scores=True)
    # Cache the attention scores for plotting later.
    self.last_attn_scores = attn_scores
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

class GlobalSelfAttention(BaseAttention):
  def call(self, x):
    """
    Apply the global self-attention mechanism to the input sequence.
    Args:
        x: A tensor of shape `(batch_size, seq_len, embedding_dim)`
        representing the input sequence.
    Returns:
        A tensor of the same shape as the input, representing the sequence
        after being transformed by the self-attention mechanism.
    """
    attn_output = self.mha(
        query=x,
        value=x,
        key=x)
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

class CausalSelfAttention(BaseAttention):
  """
  Call self attention on the input sequence, ensuring that each position in the
  output depends only on previous positions (i.e. a causal model).
  Args:
      x: Input sequence tensor of shape `(batch_size, seq_len, embed_dim)`.
  Returns:
      Output sequence tensor of the same shape as the input, after self-attention
      and residual connection with layer normalization applied.
  """
  def call(self, x):
    attn_output = self.mha(
        query=x,
        value=x,
        key=x,
        use_causal_mask = True)
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

# %% [markdown]
# ## The final CCT model

# %%
def create_cct_model(
    image_size=IMG_SIZE,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):
    inputs = layers.Input(input_shape)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(inputs)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        ###############################################################################
        # Layer normalization 1.
        x11 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
        # CausalSelfAttention
        attention_output = CausalSelfAttention(num_heads=num_heads, key_dim=projection_dim)(x11)
        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

        ###############################################################################
        # Layer normalization 1.
        x12 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
        # GlobalSelfAttention
        attention_output = GlobalSelfAttention(num_heads=num_heads, key_dim=projection_dim)(x12)
        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

        ###############################################################################
        # CrossAttention
        attention_output = CrossAttention(num_heads=num_heads, key_dim=projection_dim)(x11, x12)
        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES , activation="softmax")(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
model = create_cct_model()
#model.summary()

# %% [markdown]
# ---
#
#
# # 🧠 MS Classification: Axial - MixUp & Proposed Method

# %%
optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)
model.compile(
    optimizer=optimizer,
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Precision(),
        keras.metrics.Recall(),
        keras.metrics.AUC(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', threshold=0.5),
        ],
    )
history = model.fit(mixup_ds,
                    validation_data=val_ds_v,
                    batch_size=BATCH_SIZE,
                    class_weight=class_weights_dict,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 158s 1s/step - loss: 0.6379 - accuracy: 0.7110 - precision: 0.8691 - recall: 0.5972 - auc: 0.7191 - f1_score: 0.6895 - val_loss: 0.5587 - val_accuracy: 0.8182 - val_precision: 0.8182 - val_recall: 0.8182 - val_auc: 0.8479 - val_f1_score: 0.8179
# Epoch 2/100
# 42/42 [==============================] - 21s 467ms/step - loss: 0.5417 - accuracy: 0.7995 - precision: 0.9168 - recall: 0.6273 - auc: 0.7818 - f1_score: 0.7773 - val_loss: 0.5459 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_auc: 0.8423 - val_f1_score: 0.8000
# Epoch 3/100
# 42/42 [==============================] - 21s 465ms/step - loss: 0.5079 - accuracy: 0.8139 - precision: 0.9191 - recall: 0.6381 - auc: 0.8037 - f1_score: 0.7948 - val_loss: 0.5000 - val_accuracy: 0.8485 - val_precision: 0.8485 - val_recall: 0.8485 - val_auc: 0.8625 - val_f1_score: 0.8464
# Epoch 4/100
# 42/42 [==============================] - 21s 465ms/step - loss: 0.5024 - accuracy: 0.8116 - precision: 0.9153 - recall: 0.6406 - auc: 0.7974 - f1_score: 0.7951 - val_loss: 0.4614 - val_accuracy: 0.8424 - val_precision: 0.8424 - val_recall: 0.8424 - val_auc: 0.9061 - val_f1_score: 0.8414
# Epoch 5/100
# 42/42 [==============================] - 21s 465ms/step - loss: 0.5132 - accuracy: 0.8245 - precision: 0.9191 - recall: 0.6405 - auc: 0.7876 - f1_score: 0.7990 - val_loss: 0.4851 - val_accuracy: 0.8424 - val_precision: 0.8424 - val_recall: 0.8424 - val_auc: 0.8819 - val_f1_score: 0.8403
# Epoch 6/100
# 42/42 [==============================] - 21s 467ms/step - loss: 0.4874 - accuracy: 0.8457 - precision: 0.9395 - recall: 0.6489 - auc: 0.8045 - f1_score: 0.8219 - val_loss: 0.4629 - val_accuracy: 0.8545 - val_precision: 0.8545 - val_recall: 0.8545 - val_auc: 0.8988 - val_f1_score: 0.8519
# Epoch 7/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4829 - accuracy: 0.8442 - precision: 0.9297 - recall: 0.6468 - auc: 0.8035 - f1_score: 0.8200 - val_loss: 0.4702 - val_accuracy: 0.8364 - val_precision: 0.8364 - val_recall: 0.8364 - val_auc: 0.9065 - val_f1_score: 0.8315
# Epoch 8/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.5080 - accuracy: 0.8290 - precision: 0.9319 - recall: 0.6457 - auc: 0.8190 - f1_score: 0.8083 - val_loss: 0.4323 - val_accuracy: 0.8545 - val_precision: 0.8545 - val_recall: 0.8545 - val_auc: 0.9252 - val_f1_score: 0.8533
# Epoch 9/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.
100
# 42/42 [==============================] - 21s 461ms/step - loss: 0.3250 - accuracy: 0.9614 - precision: 0.9932 - recall: 0.6807 - auc: 0.8699 - f1_score: 0.9297 - val_loss: 0.3832 - val_accuracy: 0.8970 - val_precision: 0.8970 - val_recall: 0.8970 - val_auc: 0.9486 - val_f1_score: 0.8945
# Epoch 96/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3251 - accuracy: 0.9629 - precision: 0.9909 - recall: 0.6777 - auc: 0.8524 - f1_score: 0.9340 - val_loss: 0.3911 - val_accuracy: 0.8970 - val_precision: 0.8970 - val_recall: 0.8970 - val_auc: 0.9416 - val_f1_score: 0.8956
# Epoch 97/100
# 42/42 [==============================] - 21s 461ms/step - loss: 0.3395 - accuracy: 0.9380 - precision: 0.9834 - recall: 0.6952 - auc: 0.8711 - f1_score: 0.9146 - val_loss: 0.4136 - val_accuracy: 0.8727 - val_precision: 0.8727 - val_recall: 0.8727 - val_auc: 0.9380 - val_f1_score: 0.8721
# Epoch 98/100
# 42/42 [==============================] - 21s 460ms/step - loss: 0.3322 - accuracy: 0.9478 - precision: 0.9871 - recall: 0.6793 - auc: 0.8780 - f1_score: 0.9184 - val_loss: 0.3908 - val_accuracy: 0.8667 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9453 - val_f1_score: 0.8640
# Epoch 99/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3234 - accuracy: 0.9660 - precision: 0.9909 - recall: 0.6756 - auc: 0.8639 - f1_score: 0.9288 - val_loss: 0.3842 - val_accuracy: 0.8879 - val_precision: 0.8879 - val_recall: 0.8879 - val_auc: 0.9546 - val_f1_score: 0.8863
# Epoch 100/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.3214 - accuracy: 0.9644 - precision: 0.9909 - recall: 0.6735 - auc: 0.8673 - f1_score: 0.9307 - val_loss: 0.3893 - val_accuracy: 0.8939 - val_precision: 0.8939 - val_recall: 0.8939 - val_auc: 0.9459 - val_f1_score: 0.8907

# %% [markdown]
# ## Let's visualize the training progress of the model.

# %%
plot_training_curves(history, 'MS-Trust-MixUp (Axial Modalities)')

# %% [markdown]
# ---
#
#
# # 🧠 MS Classification: Axial - CutMix & Proposed Method

# %%
model = create_cct_model()
#model.summary()

# %%
optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)
model.compile(
    optimizer=optimizer,
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Precision(),
        keras.metrics.Recall(),
        keras.metrics.AUC(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', threshold=0.5),
        ],
    )
history = model.fit(cutmix_ds,
                    validation_data=val_ds_v,
                    batch_size=BATCH_SIZE,
                    class_weight=class_weights_dict,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 42/42 [==============================] - 34s 513ms/step - loss: 0.5996 - accuracy: 0.7171 - precision: 0.7678 - recall: 0.6886 - auc: 0.7761 - f1_score: 0.7035 - val_loss: 0.5158 - val_accuracy: 0.8273 - val_precision: 0.8273 - val_recall: 0.8273 - val_auc: 0.8675 - val_f1_score: 0.8179
# Epoch 2/100
# 42/42 [==============================] - 21s 468ms/step - loss: 0.5516 - accuracy: 0.7693 - precision: 0.8169 - recall: 0.7307 - auc: 0.8214 - f1_score: 0.7591 - val_loss: 0.4783 - val_accuracy: 0.8455 - val_precision: 0.8455 - val_recall: 0.8455 - val_auc: 0.8956 - val_f1_score: 0.8420
# Epoch 3/100
100
# 42/42 [==============================] - 21s 466ms/step - loss: 0.4899 - accuracy: 0.8230 - precision: 0.8654 - recall: 0.7725 - auc: 0.8722 - f1_score: 0.8115 - val_loss: 0.4529 - val_accuracy: 0.8394 - val_precision: 0.8394 - val_recall: 0.8394 - val_auc: 0.9202 - val_f1_score: 0.8393
# Epoch 14/100
# 42/42 [==============================] - 21s 466ms/step - loss: 0.4674 - accuracy: 0.8396 - precision: 0.8737 - recall: 0.7752 - auc: 0.8848 - f1_score: 0.8275 - val_loss: 0.4243 - val_accuracy: 0.8697 - val_precision: 0.8697 - val_recall: 0.8697 - val_auc: 0.9275 - val_f1_score: 0.8670
# Epoch 15/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.4722 - accuracy: 0.8253 - precision: 0.8616 - recall: 0.7712 - auc: 0.8812 - f1_score: 0.8178 - val_loss: 0.4152 - val_accuracy: 0.8697 - val_precision: 0.8697 - val_recall: 0.8697 - val_auc: 0.9329 - val_f1_score: 0.8670
# Epoch 16/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.4824 - accuracy: 0.8230 - precision: 0.8676 - recall: 0.7771 - auc: 0.8863 - f1_score: 0.8103 - val_loss: 0.4196 - val_accuracy: 0.8697 - val_precision: 0.8697 - val_recall: 0.8697 - val_auc: 0.9422 - val_f1_score: 0.8679
# Epoch 17/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4681 - accuracy: 0.8268 - precision: 0.8714 - recall: 0.7847 - auc: 0.8883 - f1_score: 0.8203 - val_loss: 0.4239 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9290 - val_f1_score: 0.8565
# Epoch 18/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4755 - accuracy: 0.8268 - precision: 0.8638 - recall: 0.7774 - auc: 0.8854 - f1_score: 0.8150 - val_loss: 0.4086 - val_accuracy: 0.8848 - val_precision: 0.8848 - val_recall: 0.8848 - val_auc: 0.9367 - val_f1_score: 0.8812
# Epoch 19/100
# 42/42 [==============================] - 21s 466ms/step - loss: 0.4630 - accuracy: 0.8230 - precision: 0.8616 - recall: 0.7823 - auc: 0.8934 - f1_score: 0.8162 - val_loss: 0.4269 - val_accuracy: 0.8545 - val_precision: 0.8545 - val_recall: 0.8545 - val_auc: 0.9292 - val_f1_score: 0.8538
# Epoch 20/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.4525 - accuracy: 0.8313 - precision: 0.8684 - recall: 0.7794 - auc: 0.8968 - f1_score: 0.8237 - val_loss: 0.4356 - val_accuracy: 0.8667 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9227 - val_f1_score: 0.8651
# Epoch 21/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4715 - accuracy: 0.8230 - precision: 0.8555 - recall: 0.7715 - auc: 0.8815 - f1_score: 0.8092 - val_loss: 0.4611 - val_accuracy: 0.8485 - val_precision: 0.8485 - val_recall: 0.8485 - val_auc: 0.9058 - val_f1_score: 0.8390
# Epoch 22/100
# 42/42 [==============================] - 23s 510ms/step - loss: 0.4594 - accuracy: 0.8457 - precision: 0.8782 - recall: 0.7845 - auc: 0.8851 - f1_score: 0.8348 - val_loss: 0.4276 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9262 - val_f1_score: 0.8507
# Epoch 23/100
# 42/42 [==============================] - 21s 465ms/step - loss: 0.4708 - accuracy: 0.8313 - precision: 0.8684 - recall: 0.7752 - auc: 0.8863 - f1_score: 0.8169 - val_loss: 0.3952 - val_accuracy: 0.8818 - val_precision: 0.8818 - val_recall: 0.8818 - val_auc: 0.9448 - val_f1_score: 0.8792
# Epoch 24/100
# 42/42 [==============================] - 21s 470ms/step - loss: 0.4526 - accuracy: 0.8283 - precision: 0.8737 - recall: 0.7815 - auc: 0.8994 - f1_score: 0.8187 - val_loss: 0.3993 - val_accuracy: 0.8727 - val_precision: 0.8727 - val_recall: 0.8727 - val_auc: 0.9448 - val_f1_score: 0.8702
# Epoch 25/100
# 42/42 [==============================] - 21s 471ms/step - loss: 0.4402 - accuracy: 0.8495 - precision: 0.8941 - recall: 0.7986 - auc: 0.9077 - f1_score: 0.8409 - val_loss: 0.4129 - val_accuracy: 0.8667 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9332 - val_f1_score: 0.8645
# Epoch 26/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4553 - accuracy: 0.8404 - precision: 0.8888 - recall: 0.7907 - auc: 0.8992 - f1_score: 0.8309 - val_loss: 0.4199 - val_accuracy: 0.8667 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9346 - val_f1_score: 0.8627
# Epoch 27/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4431 - accuracy: 0.8540 - precision: 0.8918 - recall: 0.7999 - auc: 0.9045 - f1_score: 0.8406 - val_loss: 0.4283 - val_accuracy: 0.8545 - val_precision: 0.8545 - val_recall: 0.8545 - val_auc: 0.9290 - val_f1_score: 0.8539
# Epoch 28/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.4772 - accuracy: 0.8230 - precision: 0.8691 - recall: 0.7727 - auc: 0.8890 - f1_score: 0.8072 - val_loss: 0.4321 - val_accuracy: 0.8424 - val_precision: 0.8424 - val_recall: 0.8424 - val_auc: 0.9271 - val_f1_score: 0.8421
# Epoch 29/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4535 - accuracy: 0.8260 - precision: 0.8684 - recall: 0.7820 - auc: 0.8984 - f1_score: 0.8112 - val_loss: 0.4294 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9268 - val_f1_score: 0.8568
# Epoch 30/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.4314 - accuracy: 0.8669 - precision: 0.9062 - recall: 0.8073 - auc: 0.9116 - f1_score: 0.8579 - val_loss: 0.3974 - val_accuracy: 0.8848 - val_precision: 0.8848 - val_recall: 0.8848 - val_auc: 0.9415 - val_f1_score: 0.8830
# Epoch 31/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.4151 - accuracy: 0.8691 - precision: 0.9100 - recall: 0.8112 - auc: 0.9228 - f1_score: 0.8593 - val_loss: 0.4054 - val_accuracy: 0.8727 - val_precision: 0.8727 - val_recall: 0.8727 - val_auc: 0.9391 - val_f1_score: 0.8715
# Epoch 32/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4179 - accuracy: 0.8691 - precision: 0.8986 - recall: 0.7995 - auc: 0.9152 - f1_score: 0.8549 - val_loss: 0.4160 - val_accuracy: 0.8697 - val_precision: 0.8697 - val_recall: 0.8697 - val_auc: 0.9333 - val_f1_score: 0.8687
# Epoch 33/100
# 42/42 [==============================] - 21s 465ms/step - loss: 0.4376 - accuracy: 0.8525 - precision: 0.8873 - recall: 0.7931 - auc: 0.9053 - f1_score: 0.8394 - val_loss: 0.4185 - val_accuracy: 0.8545 - val_precision: 0.8545 - val_recall: 0.8545 - val_auc: 0.9337 - val_f1_score: 0.8538
# Epoch 34/100
# 42/42 [==============================] - 21s 461ms/step - loss: 0.4342 - accuracy: 0.8570 - precision: 0.8941 - recall: 0.7933 - auc: 0.9101 - f1_score: 0.8477 - val_loss: 0.4071 - val_accuracy: 0.8758 - val_precision: 0.8758 - val_recall: 0.8758 - val_auc: 0.9385 - val_f1_score: 0.8738
# Epoch 35/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4274 - accuracy: 0.8548 - precision: 0.8986 - recall: 0.7962 - auc: 0.9121 - f1_score: 0.8450 - val_loss: 0.4106 - val_accuracy: 0.8636 - val_precision: 0.8636 - val_recall: 0.8636 - val_auc: 0.9357 - val_f1_score: 0.8624
# Epoch 36/100
# 42/42 [==============================] - 21s 461ms/step - loss: 0.4316 - accuracy: 0.8548 - precision: 0.8911 - recall: 0.7997 - auc: 0.9113 - f1_score: 0.8444 - val_loss: 0.4006 - val_accuracy: 0.8848 - val_precision: 0.8848 - val_recall: 0.8848 - val_auc: 0.9390 - val_f1_score: 0.8819
# Epoch 37/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.4158 - accuracy: 0.8661 - precision: 0.9100 - recall: 0.8101 - auc: 0.9165 - f1_score: 0.8583 - val_loss: 0.4033 - val_accuracy: 0.8697 - val_precision: 0.8697 - val_recall: 0.8697 - val_auc: 0.9397 - val_f1_score: 0.8674
# Epoch 38/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.4353 - accuracy: 0.8676 - precision: 0.9032 - recall: 0.8068 - auc: 0.9054 - f1_score: 0.8580 - val_loss: 0.3939 - val_accuracy: 0.8909 - val_precision: 0.8909 - val_recall: 0.8909 - val_auc: 0.9431 - val_f1_score: 0.8881
# Epoch 39/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4220 - accuracy: 0.8585 - precision: 0.8903 - recall: 0.7996 - auc: 0.9132 - f1_score: 0.8499 - val_loss: 0.4129 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9367 - val_f1_score: 0.8776
# Epoch 40/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4195 - accuracy: 0.8684 - precision: 0.8994 - recall: 0.8077 - auc: 0.9115 - f1_score: 0.8573 - val_loss: 0.3968 - val_accuracy: 0.8606 - val_precision: 0.8606 - val_recall: 0.8606 - val_auc: 0.9450 - val_f1_score: 0.8593
# Epoch 41/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.4056 - accuracy: 0.8699 - precision: 0.9047 - recall: 0.8087 - auc: 0.9245 - f1_score: 0.8575 - val_loss: 0.3943 - val_accuracy: 0.8697 - val_precision: 0.8697 - val_recall: 0.8697 - val_auc: 0.9454 - val_f1_score: 0.8672
# Epoch 42/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.4233 - accuracy: 0.8608 - precision: 0.8964 - recall: 0.8012 - auc: 0.9129 - f1_score: 0.8469 - val_loss: 0.4012 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9404 - val_f1_score: 0.8737
# Epoch 43/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4198 - accuracy: 0.8782 - precision: 0.9100 - recall: 0.8123 - auc: 0.9121 - f1_score: 0.8649 - val_loss: 0.4249 - val_accuracy: 0.8667 - val_precision: 0.8667 - val_recall: 0.8667 - val_auc: 0.9282 - val_f1_score: 0.8654
# Epoch 44/100
# 42/42 [==============================] - 21s 471ms/step - loss: 0.4227 - accuracy: 0.8744 - precision: 0.9107 - recall: 0.8179 - auc: 0.9176 - f1_score: 0.8623 - val_loss: 0.3804 - val_accuracy: 0.8879 - val_precision: 0.8879 - val_recall: 0.8879 - val_auc: 0.9535 - val_f1_score: 0.8867
# Epoch 45/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.4054 - accuracy: 0.8790 - precision: 0.9145 - recall: 0.8180 - auc: 0.9209 - f1_score: 0.8693 - val_loss: 0.3725 - val_accuracy: 0.8970 - val_precision: 0.8970 - val_recall: 0.8970 - val_auc: 0.9539 - val_f1_score: 0.8947
# Epoch 46/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3764 - accuracy: 0.8964 - precision: 0.9327 - recall: 0.8236 - auc: 0.9320 - f1_score: 0.8863 - val_loss: 0.4006 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9436 - val_f1_score: 0.8773
# Epoch 47/100
# 42/42 [==============================] - 21s 461ms/step - loss: 0.3997 - accuracy: 0.8790 - precision: 0.9175 - recall: 0.8119 - auc: 0.9252 - f1_score: 0.8668 - val_loss: 0.3907 - val_accuracy: 0.8879 - val_precision: 0.8879 - val_recall: 0.8879 - val_auc: 0.9460 - val_f1_score: 0.8858
# Epoch 48/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.4294 - accuracy: 0.8638 - precision: 0.8971 - recall: 0.8041 - auc: 0.9095 - f1_score: 0.8551 - val_loss: 0.3792 - val_accuracy: 0.8818 - val_precision: 0.8818 - val_recall: 0.8818 - val_auc: 0.9557 - val_f1_score: 0.8798
# Epoch 49/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.4024 - accuracy: 0.8790 - precision: 0.9032 - recall: 0.8178 - auc: 0.9225 - f1_score: 0.8692 - val_loss: 0.3702 - val_accuracy: 0.8879 - val_precision: 0.8879 - val_recall: 0.8879 - val_auc: 0.9559 - val_f1_score: 0.8849
# Epoch 50/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.3856 - accuracy: 0.8896 - precision: 0.9191 - recall: 0.8271 - auc: 0.9306 - f1_score: 0.8850 - val_loss: 0.3816 - val_accuracy: 0.8879 - val_precision: 0.8879 - val_recall: 0.8879 - val_auc: 0.9525 - val_f1_score: 0.8859
# Epoch 51/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4020 - accuracy: 0.8850 - precision: 0.9123 - recall: 0.8238 - auc: 0.9223 - f1_score: 0.8726 - val_loss: 0.4520 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9118 - val_f1_score: 0.8484
# Epoch 52/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.3797 - accuracy: 0.8979 - precision: 0.9251 - recall: 0.8320 - auc: 0.9344 - f1_score: 0.8879 - val_loss: 0.3744 - val_accuracy: 0.8758 - val_precision: 0.8758 - val_recall: 0.8758 - val_auc: 0.9565 - val_f1_score: 0.8742
# Epoch 53/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4047 - accuracy: 0.8737 - precision: 0.9115 - recall: 0.8158 - auc: 0.9265 - f1_score: 0.8657 - val_loss: 0.4195 - val_accuracy: 0.8515 - val_precision: 0.8515 - val_recall: 0.8515 - val_auc: 0.9337 - val_f1_score: 0.8507
# Epoch 54/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3836 - accuracy: 0.8843 - precision: 0.9183 - recall: 0.8225 - auc: 0.9322 - f1_score: 0.8756 - val_loss: 0.3944 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9470 - val_f1_score: 0.8776
# Epoch 55/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.4158 - accuracy: 0.8744 - precision: 0.9130 - recall: 0.8183 - auc: 0.9196 - f1_score: 0.8663 - val_loss: 0.4432 - val_accuracy: 0.8455 - val_precision: 0.8455 - val_recall: 0.8455 - val_auc: 0.9221 - val_f1_score: 0.8454
# Epoch 56/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.4069 - accuracy: 0.8676 - precision: 0.9115 - recall: 0.8066 - auc: 0.9235 - f1_score: 0.8566 - val_loss: 0.3952 - val_accuracy: 0.8818 - val_precision: 0.8818 - val_recall: 0.8818 - val_auc: 0.9442 - val_f1_score: 0.8808
# Epoch 57/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3853 - accuracy: 0.8896 - precision: 0.9312 - recall: 0.8318 - auc: 0.9332 - f1_score: 0.8835 - val_loss: 0.4006 - val_accuracy: 0.8818 - val_precision: 0.8818 - val_recall: 0.8818 - val_auc: 0.9400 - val_f1_score: 0.8794
# Epoch 58/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.3963 - accuracy: 0.8911 - precision: 0.9244 - recall: 0.8279 - auc: 0.9255 - f1_score: 0.8806 - val_loss: 0.3945 - val_accuracy: 0.8758 - val_precision: 0.8758 - val_recall: 0.8758 - val_auc: 0.9467 - val_f1_score: 0.8752
# Epoch 59/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.3912 - accuracy: 0.8850 - precision: 0.9198 - recall: 0.8317 - auc: 0.9296 - f1_score: 0.8750 - val_loss: 0.3889 - val_accuracy: 0.8848 - val_precision: 0.8848 - val_recall: 0.8848 - val_auc: 0.9473 - val_f1_score: 0.8826
# Epoch 60/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.3879 - accuracy: 0.8873 - precision: 0.9221 - recall: 0.8253 - auc: 0.9343 - f1_score: 0.8765 - val_loss: 0.3766 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9529 - val_f1_score: 0.8764
# Epoch 61/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.3709 - accuracy: 0.8986 - precision: 0.9297 - recall: 0.8310 - auc: 0.9377 - f1_score: 0.8878 - val_loss: 0.3752 - val_accuracy: 0.8909 - val_precision: 0.8909 - val_recall: 0.8909 - val_auc: 0.9551 - val_f1_score: 0.8897
# Epoch 62/100
# 42/42 [==============================] - 21s 466ms/step - loss: 0.3866 - accuracy: 0.8797 - precision: 0.9175 - recall: 0.8218 - auc: 0.9385 - f1_score: 0.8682 - val_loss: 0.3763 - val_accuracy: 0.8818 - val_precision: 0.8818 - val_recall: 0.8818 - val_auc: 0.9547 - val_f1_score: 0.8796
# Epoch 63/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.3698 - accuracy: 0.9017 - precision: 0.9342 - recall: 0.8328 - auc: 0.9400 - f1_score: 0.8942 - val_loss: 0.3916 - val_accuracy: 0.8909 - val_precision: 0.8909 - val_recall: 0.8909 - val_auc: 0.9456 - val_f1_score: 0.8891
# Epoch 64/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.3850 - accuracy: 0.8926 - precision: 0.9259 - recall: 0.8287 - auc: 0.9335 - f1_score: 0.8843 - val_loss: 0.3907 - val_accuracy: 0.8758 - val_precision: 0.8758 - val_recall: 0.8758 - val_auc: 0.9487 - val_f1_score: 0.8734
# Epoch 65/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.3708 - accuracy: 0.9024 - precision: 0.9334 - recall: 0.8366 - auc: 0.9436 - f1_score: 0.8924 - val_loss: 0.4133 - val_accuracy: 0.8727 - val_precision: 0.8727 - val_recall: 0.8727 - val_auc: 0.9371 - val_f1_score: 0.8714
# Epoch 66/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3645 - accuracy: 0.8979 - precision: 0.9380 - recall: 0.8407 - auc: 0.9418 - f1_score: 0.8951 - val_loss: 0.4125 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9382 - val_f1_score: 0.8757
# Epoch 67/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3614 - accuracy: 0.9024 - precision: 0.9251 - recall: 0.8354 - auc: 0.9410 - f1_score: 0.8932 - val_loss: 0.3997 - val_accuracy: 0.8848 - val_precision: 0.8848 - val_recall: 0.8848 - val_auc: 0.9409 - val_f1_score: 0.8821
# Epoch 68/100
# 42/42 [==============================] - 21s 461ms/step - loss: 0.3615 - accuracy: 0.9107 - precision: 0.9387 - recall: 0.8431 - auc: 0.9416 - f1_score: 0.8995 - val_loss: 0.4041 - val_accuracy: 0.8939 - val_precision: 0.8939 - val_recall: 0.8939 - val_auc: 0.9380 - val_f1_score: 0.8915
# Epoch 69/100
# 42/42 [==============================] - 21s 461ms/step - loss: 0.3728 - accuracy: 0.8918 - precision: 0.9213 - recall: 0.8325 - auc: 0.9439 - f1_score: 0.8836 - val_loss: 0.3840 - val_accuracy: 0.8879 - val_precision: 0.8879 - val_recall: 0.8879 - val_auc: 0.9494 - val_f1_score: 0.8856
# Epoch 70/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0
# 42/42 [==============================] - 21s 469ms/step - loss: 0.3700 - accuracy: 0.9062 - precision: 0.9418 - recall: 0.8401 - auc: 0.9483 - f1_score: 0.8931 - val_loss: 0.3715 - val_accuracy: 0.8939 - val_precision: 0.8939 - val_recall: 0.8939 - val_auc: 0.9549 - val_f1_score: 0.8923
# Epoch 82/100
# 42/42 [==============================] - 21s 470ms/step - loss: 0.3541 - accuracy: 0.9123 - precision: 0.9410 - recall: 0.8486 - auc: 0.9448 - f1_score: 0.9002 - val_loss: 0.3740 - val_accuracy: 0.9030 - val_precision: 0.9030 - val_recall: 0.9030 - val_auc: 0.9543 - val_f1_score: 0.9002
# Epoch 83/100
# 42/42 [==============================] - 21s 467ms/step - loss: 0.3440 - accuracy: 0.9213 - precision: 0.9493 - recall: 0.8631 - auc: 0.9571 - f1_score: 0.9144 - val_loss: 0.4172 - val_accuracy: 0.8758 - val_precision: 0.8758 - val_recall: 0.8758 - val_auc: 0.9352 - val_f1_score: 0.8742
# Epoch 84/100
# 42/42 [==============================] - 21s 467ms/step - loss: 0.3572 - accuracy: 0.9123 - precision: 0.9395 - recall: 0.8460 - auc: 0.9463 - f1_score: 0.9020 - val_loss: 0.4098 - val_accuracy: 0.8788 - val_precision: 0.8788 - val_recall: 0.8788 - val_auc: 0.9359 - val_f1_score: 0.8780
# Epoch 85/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.3518 - accuracy: 0.9100 - precision: 0.9402 - recall: 0.8496 - auc: 0.9486 - f1_score: 0.9063 - val_loss: 0.3745 - val_accuracy: 0.8939 - val_precision: 0.8939 - val_recall: 0.8939 - val_auc: 0.9536 - val_f1_score: 0.8930
# Epoch 86/100
# 42/42 [==============================] - 21s 466ms/step - loss: 0.3643 - accuracy: 0.9024 - precision: 0.9380 - recall: 0.8356 - auc: 0.9383 - f1_score: 0.8965 - val_loss: 0.3685 - val_accuracy: 0.9091 - val_precision: 0.9091 - val_recall: 0.9091 - val_auc: 0.9570 - val_f1_score: 0.9077
# Epoch 87/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.3456 - accuracy: 0.9115 - precision: 0.9410 - recall: 0.8526 - auc: 0.9501 - f1_score: 0.9075 - val_loss: 0.3696 - val_accuracy: 0.9091 - val_precision: 0.9091 - val_recall: 0.9091 - val_auc: 0.9553 - val_f1_score: 0.9076
# Epoch 88/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.3775 - accuracy: 0.8933 - precision: 0.9289 - recall: 0.8281 - auc: 0.9390 - f1_score: 0.8865 - val_loss: 0.3874 - val_accuracy: 0.8818 - val_precision: 0.8818 - val_recall: 0.8818 - val_auc: 0.9469 - val_f1_score: 0.8800
# Epoch 89/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.3612 - accuracy: 0.9054 - precision: 0.9387 - recall: 0.8368 - auc: 0.9418 - f1_score: 0.8973 - val_loss: 0.3839 - val_accuracy: 0.8879 - val_precision: 0.8879 - val_recall: 0.8879 - val_auc: 0.9446 - val_f1_score: 0.8859
# Epoch 90/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3556 - accuracy: 0.9168 - precision: 0.9470 - recall: 0.8459 - auc: 0.9415 - f1_score: 0.9070 - val_loss: 0.4009 - val_accuracy: 0.8909 - val_precision: 0.8909 - val_recall: 0.8909 - val_auc: 0.9420 - val_f1_score: 0.8899
# Epoch 91/100
# 42/42 [==============================] - 21s 463ms/step - loss: 0.3548 - accuracy: 0.9145 - precision: 0.9410 - recall: 0.8349 - auc: 0.9388 - f1_score: 0.9058 - val_loss: 0.3931 - val_accuracy: 0.8727 - val_precision: 0.8727 - val_recall: 0.8727 - val_auc: 0.9447 - val_f1_score: 0.8710
# Epoch 92/100
# 42/42 [==============================] - 21s 464ms/step - loss: 0.3379 - accuracy: 0.9297 - precision: 0.9554 - recall: 0.8569 - auc: 0.9535 - f1_score: 0.9189 - val_loss: 0.3995 - val_accuracy: 0.8909 - val_precision: 0.8909 - val_recall: 0.8909 - val_auc: 0.9372 - val_f1_score: 0.8894
# Epoch 93/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3537 - accuracy: 0.9206 - precision: 0.9478 - recall: 0.8489 - auc: 0.9482 - f1_score: 0.9092 - val_loss: 0.3869 - val_accuracy: 0.8909 - val_precision: 0.8909 - val_recall: 0.8909 - val_auc: 0.9472 - val_f1_score: 0.8891
# Epoch 94/100
# 42/42 [==============================] - 21s 461ms/step - loss: 0.3439 - accuracy: 0.9123 - precision: 0.9418 - recall: 0.8498 - auc: 0.9521 - f1_score: 0.9054 - val_loss: 0.4409 - val_accuracy: 0.8636 - val_precision: 0.8636 - val_recall: 0.8636 - val_auc: 0.9219 - val_f1_score: 0.8635
# Epoch 95/100
# 42/42 [==============================] - 21s 461ms/step - loss: 0.3732 - accuracy: 0.8949 - precision: 0.9304 - recall: 0.8322 - auc: 0.9361 - f1_score: 0.8905 - val_loss: 0.3880 - val_accuracy: 0.8970 - val_precision: 0.8970 - val_recall: 0.8970 - val_auc: 0.9435 - val_f1_score: 0.8953
# Epoch 96/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3448 - accuracy: 0.9191 - precision: 0.9455 - recall: 0.8475 - auc: 0.9476 - f1_score: 0.9100 - val_loss: 0.3694 - val_accuracy: 0.8848 - val_precision: 0.8848 - val_recall: 0.8848 - val_auc: 0.9569 - val_f1_score: 0.8830
# Epoch 97/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3637 - accuracy: 0.9092 - precision: 0.9425 - recall: 0.8436 - auc: 0.9414 - f1_score: 0.8977 - val_loss: 0.3621 - val_accuracy: 0.9030 - val_precision: 0.9030 - val_recall: 0.9030 - val_auc: 0.9577 - val_f1_score: 0.9004
# Epoch 98/100
# 42/42 [==============================] - 21s 465ms/step - loss: 0.3367 - accuracy: 0.9274 - precision: 0.9599 - recall: 0.8586 - auc: 0.9544 - f1_score: 0.9212 - val_loss: 0.3777 - val_accuracy: 0.9000 - val_precision: 0.9000 - val_recall: 0.9000 - val_auc: 0.9467 - val_f1_score: 0.8974
# Epoch 99/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3326 - accuracy: 0.9228 - precision: 0.9569 - recall: 0.8565 - auc: 0.9537 - f1_score: 0.9165 - val_loss: 0.3768 - val_accuracy: 0.8909 - val_precision: 0.8909 - val_recall: 0.8909 - val_auc: 0.9491 - val_f1_score: 0.8886
# Epoch 100/100
# 42/42 [==============================] - 21s 462ms/step - loss: 0.3421 - accuracy: 0.9228 - precision: 0.9554 - recall: 0.8511 - auc: 0.9531 - f1_score: 0.9123 - val_loss: 0.3716 - val_accuracy: 0.8970 - val_precision: 0.8970 - val_recall: 0.8970 - val_auc: 0.9557 - val_f1_score: 0.8953

# %% [markdown]
# ## Let's visualize the training progress of the model.

# %%
plot_training_curves(history, 'MS-Trust-CutMix (Axial Modalities)')
