# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhaAlzahrani/MS_Trust/blob/main/MS_Trust_DualAtten_MS_Both.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 MS Classification: Transformer Model with Causal-Global Dual Attention

# %%
# !pip install -U -q tensorflow-addons
# !pip install nest_asyncio
# !pip install keras-cv tensorflow --upgrade
# Out:
#       Successfully uninstalled tensorflow-2.14.0
# Successfully installed keras-2.15.0 keras-core-0.1.7 keras-cv-0.6.4 namex-0.0.7 tensorboard-2.15.1 tensorflow-2.15.0 tensorflow-estimator-2.15.0

# %%
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory
import keras_cv

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import numpy as np
from google.colab import drive
from sklearn.utils.class_weight import compute_class_weight
from sklearn.utils import class_weight

# Define the path to the MRI data directory
drive.mount('/content/drive', force_remount=True)

import nest_asyncio
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 🈺 Hyperparameters

# %%
######################
NUM_CLASSES = 4
######################
positional_emb = True
conv_layers = 2
projection_dim = 128
num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
transformer_layers = 2
stochastic_depth_rate = 0.1
learning_rate = 0.001
weight_decay = 0.0001
NUM_EPOCHS = 100
IMG_SIZE =224
BATCH_SIZE = 32
input_shape = (IMG_SIZE, IMG_SIZE, 3)
np.random.seed(42)
tf.random.set_seed(42)
AUTO = tf.data.AUTOTUNE

# %%
def preprocess_image(path):
    image = tf.keras.utils.load_img(path)
    image = tf.image.central_crop(image, central_fraction=0.9)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = tf.image.convert_image_dtype(image, tf.float32) / 255.0
    return image

# %%
def plot_training_curves(history, title):
    loss = np.array(history.history['loss'])
    val_loss = np.array(history.history['val_loss'])
    accuracy = np.array(history.history['accuracy'])
    val_accuracy = np.array(history.history['val_accuracy'])
    epochs = range(len(history.history['loss']))
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))

    # Plot loss
    ax1.plot(epochs, loss, label='training_loss', marker='.')
    ax1.plot(epochs, val_loss, label='val_loss', marker='.')
    ax1.fill_between(epochs, loss, val_loss, where=(loss > val_loss), color='C0', alpha=0.3, interpolate=True)
    ax1.fill_between(epochs, loss, val_loss, where=(loss < val_loss), color='C1', alpha=0.3, interpolate=True)
    ax1.set_title('Loss: '+title, fontsize=16)
    ax1.set_xlabel('Epochs', fontsize=14)
    ax1.legend()

    # Plot accuracy
    ax2.plot(epochs, accuracy, label='training_accuracy', marker='.')
    ax2.plot(epochs, val_accuracy, label='val_accuracy', marker='.')
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy > val_accuracy), color='C0', alpha=0.3, interpolate=True)
    ax2.fill_between(epochs, accuracy, val_accuracy, where=(accuracy < val_accuracy), color='C1', alpha=0.3, interpolate=True)
    ax2.set_title('Accuracy: '+title, fontsize=16)
    ax2.set_xlabel('Epochs', fontsize=14)
    ax2.legend();

# %% [markdown]
# ---
# # 🧠 Both

# %%
path = '/content/drive/MyDrive/Multiple_Sclerosis_Dataset/Both/'
# train data
train_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(IMG_SIZE,IMG_SIZE),
    color_mode='rgb',
    #shuffle=True,
    seed=128,
    validation_split=0.2,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
# validation data
val_ds = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='int',
    batch_size=32,
    image_size=(IMG_SIZE,IMG_SIZE),
    color_mode='rgb',
    #shuffle=True,
    seed=128,
    validation_split=0.2,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False,
)
#Configure the dataset for performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 3427 files belonging to 4 classes.
# Using 2742 files for training.
# Found 3427 files belonging to 4 classes.
# Using 685 files for validation.

# %%
#label_mode='categorical',
train_ds_cat = image_dataset_from_directory(
    directory= path,
    labels='inferred',
    label_mode='categorical',
    batch_size=32,
    image_size=(IMG_SIZE,IMG_SIZE),
)
class_names = train_ds_cat.class_names
num_images_per_class = []
for label in class_names:
    dir_name = path + label
    num_images_per_class.append(len([name for name in os.listdir(dir_name)]))
# y_train=list of train labels wrt to given directory format
y_train=[]
for i in range(0, len(num_images_per_class)):
    y_train+=[i]*num_images_per_class[i]
classes = list()
for i in range(NUM_CLASSES): classes.append(i)
class_weights=compute_class_weight(class_weight="balanced",classes=classes, y=np.asarray(y_train))
class_weights_dict = {}
for i in range(len(class_weights)):
   class_weights_dict[i] = class_weights[i]
class_weights_dict
# Out:
# Found 3427 files belonging to 4 classes.
# {0: 0.8550399201596807,
#  1: 0.8449211045364892,
#  2: 1.3180769230769231,
#  3: 1.125821287779238}

# %% [markdown]
# # 🅰 Data augmentation

# %%
def to_dict(image, label):
    image = tf.cast(image, tf.float32)
    label = tf.one_hot(label, NUM_CLASSES)
    return {"images": image, "labels": label}

def preprocess_for_model(inputs):
    images, labels = inputs["images"], inputs["labels"]
    images = tf.cast(images, tf.float32)
    return images, labels

mixup = keras_cv.layers.MixUp()
cutmix = keras_cv.layers.CutMix(alpha=0.02)
randaug = keras_cv.layers.RandAugment(value_range=(0, 255), augmentations_per_image=3, magnitude=0.5)

#No augmentation
train_ds_v = train_ds.map(to_dict)
train_ds_v = train_ds_v.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
train_ds_v = train_ds_v.prefetch(AUTOTUNE)
val_ds_v = val_ds.map(to_dict)
val_ds_v = val_ds_v.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
val_ds_v = val_ds_v.prefetch(AUTOTUNE) #Use this for fit

# %%
def aug_pipeline1(samples):
    samples = mixup(samples, training=True)
    return samples
def aug_pipeline2(samples):
    samples = cutmix(samples, training=True)
    return samples
def aug_pipeline3(samples):
    samples = randaug(samples, training=True)
    return samples

#RandAug
randaug_ds = train_ds.shuffle(1000).map(to_dict)
randaug_ds = randaug_ds.map(aug_pipeline3)
randaug_ds = randaug_ds.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
randaug_ds = randaug_ds.prefetch(AUTOTUNE) #Use this for fit

#MixUp
mixup_ds = train_ds.shuffle(1000).map(to_dict)
mixup_ds = mixup_ds.map(aug_pipeline1)
mixup_ds = mixup_ds.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
mixup_ds = mixup_ds.prefetch(AUTOTUNE) #Use this for fit
#CutMix
cutmix_ds = train_ds.shuffle(1000).map(to_dict)
cutmix_ds = cutmix_ds.map(aug_pipeline2)
cutmix_ds = cutmix_ds.map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
cutmix_ds = cutmix_ds.prefetch(AUTOTUNE) #Use this for fit

# %% [markdown]
# ---
#
#
# ## ⛓ The CCT tokenizer
#
# The first recipe introduced by the CCT authors is the tokenizer for processing the images. In a standard ViT, images are organized into uniform non-overlapping patches. This eliminates the boundary-level information present in between different patches. This is important for a neural network to effectively exploit the locality information. The figure below presents an illustration of how images are organized into patches.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We already know that convolutions are quite good at exploiting locality information. So, based on this, the authors introduce an all-convolution mini-network to produce image patches.

# %%
#https://keras.io/examples/vision/cct/
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super().__init__(**kwargs)
        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )
        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]
            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %% [markdown]
# ## Stochastic depth for regularization
#
# Stochastic depth is a regularization technique that randomly drops a set of layers. During inference, the layers are kept as they are. It is very much similar to Dropout but only that it operates on a block of layers rather than individual nodes present inside a layer. In CCT, stochastic depth is used just before the residual blocks of a Transformers encoder.

# %%
# Referred from: github.com:rwightman/pytorch-image-models.
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prop
    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (tf.shape(x).shape[0] - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %% [markdown]
# ## MLP for the Transformers encoder

# %%
class SqueezeExcite(layers.Layer):
    """Applies squeeze and excitation to input feature maps as seen in https://arxiv.org/abs/1709.01507.
    Args:         ratio: The ratio with which the feature map needs to be reduced in the reduction phase.
    Inputs:         Convolutional features.
    Outputs:        Attention modified feature maps.
    """
    def __init__(self, ratio, **kwargs):
        super().__init__(**kwargs)
        self.ratio = ratio
    def get_config(self):
        config = super().get_config()
        config.update({"ratio": self.ratio})
        return config
    def build(self, input_shape):
        filters = input_shape[-1]
        self.squeeze = layers.GlobalAveragePooling2D(keepdims=True)
        self.reduction = layers.Dense(
            units=filters // self.ratio, activation="relu", use_bias=False,
        )
        self.excite = layers.Dense(units=filters, activation="sigmoid", use_bias=False)
        self.multiply = layers.Multiply()
    def call(self, x):
        shortcut = x
        x = self.squeeze(x)
        x = self.reduction(x)
        x = self.excite(x)
        x = self.multiply([shortcut, x])
        return x
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        SqueezeExcite(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %% [markdown]
# ## Attention layers

# %%
class BaseAttention(tf.keras.layers.Layer):
  """
  Base Attention layer class that contains a MultiHeadAttention, LayerNormalization and Add layer.
  """
  def __init__(self, **kwargs):
    super().__init__()
    self.mha = tf.keras.layers.MultiHeadAttention(**kwargs)
    self.layernorm = tf.keras.layers.LayerNormalization()
    self.add = tf.keras.layers.Add()

class CrossAttention(BaseAttention):
  """
  A class that implements cross-attention mechanism by inheriting from BaseAttention class.
  Cross-attention is used to process two different sequences and attends to the context sequence while processing the query sequence.
  """
  def call(self, x, context):
    """
    The call function that performs the cross-attention operation.
    Args:
        x: The query sequence tensor, shape=(batch_size, seq_len, embedding_dim)
        context: The context sequence tensor, shape=(batch_size, seq_len, embedding_dim)
    Returns:
        The attended output tensor, shape=(batch_size, seq_len, embedding_dim)
    """
    attn_output, attn_scores = self.mha(
        query=x,
        key=context,
        value=context,
        return_attention_scores=True)
    # Cache the attention scores for plotting later.
    self.last_attn_scores = attn_scores
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

class GlobalSelfAttention(BaseAttention):
  def call(self, x):
    """
    Apply the global self-attention mechanism to the input sequence.
    Args:
        x: A tensor of shape `(batch_size, seq_len, embedding_dim)`
        representing the input sequence.
    Returns:
        A tensor of the same shape as the input, representing the sequence
        after being transformed by the self-attention mechanism.
    """
    attn_output = self.mha(
        query=x,
        value=x,
        key=x)
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

class CausalSelfAttention(BaseAttention):
  """
  Call self attention on the input sequence, ensuring that each position in the
  output depends only on previous positions (i.e. a causal model).
  Args:
      x: Input sequence tensor of shape `(batch_size, seq_len, embed_dim)`.
  Returns:
      Output sequence tensor of the same shape as the input, after self-attention
      and residual connection with layer normalization applied.
  """
  def call(self, x):
    attn_output = self.mha(
        query=x,
        value=x,
        key=x,
        use_causal_mask = True)
    x = self.add([x, attn_output])
    x = self.layernorm(x)
    return x

# %% [markdown]
# ## The final  model

# %%
def create_cct_model(
    image_size=IMG_SIZE,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):
    inputs = layers.Input(input_shape)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(inputs)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        ###############################################################################
        # Layer normalization 1.
        x11 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
        # CausalSelfAttention
        attention_output = CausalSelfAttention(num_heads=num_heads, key_dim=projection_dim)(x11)
        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

        ###############################################################################
        # Layer normalization 1.
        x12 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
        # GlobalSelfAttention
        attention_output = GlobalSelfAttention(num_heads=num_heads, key_dim=projection_dim)(x12)
        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

        ###############################################################################
        # CrossAttention
        attention_output = CrossAttention(num_heads=num_heads, key_dim=projection_dim)(x11, x12)
        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)
        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(NUM_CLASSES , activation="softmax")(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    return model

# %%
model = create_cct_model()
#model.summary()

# %% [markdown]
# ---
#
#
# # 🧠 MS Classification: Both & Proposed Method

# %%
optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)
model.compile(
    optimizer=optimizer,
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Precision(),
        keras.metrics.Recall(),
        keras.metrics.AUC(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', threshold=0.5),
        ],
    )
history = model.fit(mixup_ds,
                    validation_data=val_ds_v,
                    batch_size=BATCH_SIZE,
                    class_weight=class_weights_dict,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 86/86 [==============================] - 275s 962ms/step - loss: 1.2022 - accuracy: 0.5562 - precision: 0.7772 - recall: 0.2579 - auc: 0.7000 - f1_score: 0.4218 - val_loss: 0.9017 - val_accuracy: 0.7080 - val_precision: 0.7746 - val_recall: 0.5869 - val_auc: 0.9015 - val_f1_score: 0.5602
# Epoch 2/100
# 86/86 [==============================] - 43s 459ms/step - loss: 1.0351 - accuracy: 0.6557 - precision: 0.8453 - recall: 0.3324 - auc: 0.7490 - f1_score: 0.5397 - val_loss: 0.8326 - val_accuracy: 0.7270 - val_precision: 0.7912 - val_recall: 0.6307 - val_auc: 0.9283 - val_f1_score: 0.6550
# Epoch 3/100
# 86/86 [==============================] - 43s 458ms/step - loss: 0.9741 - accuracy: 0.6980 - precision: 0.8470 - recall: 0.3830 - auc: 0.7545 - f1_score: 0.6213 - val_loss: 0.8057 - val_accuracy: 0.7460 - val_precision: 0.7756 - val_recall: 0.6861 - val_auc: 0.9299 - val_f1_score: 0.7162
# Epoch 4/100
# 86/86 [==============================] - 43s 459ms/step - loss: 0.9173 - accuracy: 0.7261 - precision: 0.8682 - recall: 0.4118 - auc: 0.7808 - f1_score: 0.6608 - val_loss: 0.7894 - val_accuracy: 0.7781 - val_precision: 0.8244 - val_recall: 0.7197 - val_auc: 0.9409 - val_f1_score: 0.7513
# Epoch 5/100
# 86/86 [==============================] - 43s 460ms/step - loss: 0
# Epoch 100/100
# 86/86 [==============================] - 43s 462ms/step - loss: 0.5960 - accuracy: 0.9212 - precision: 0.9755 - recall: 0.5359 - auc: 0.8247 - f1_score: 0.8778 - val_loss: 0.5329 - val_accuracy: 0.9139 - val_precision: 0.9170 - val_recall: 0.9036 - val_auc: 0.9830 - val_f1_score: 0.9057

# %% [markdown]
# ## Let's visualize the training progress of the model.

# %%
plot_training_curves(history, 'MS-Trust-MixUp (Both Modalities)')

# %% [markdown]
# ---
#
#
# # 🧠 MS Classification: Both & Proposed Method

# %%
model = create_cct_model()
#model.summary()

# %%
optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)
model.compile(
    optimizer=optimizer,
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Precision(),
        keras.metrics.Recall(),
        keras.metrics.AUC(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', threshold=0.5),
        ],
    )
history = model.fit(cutmix_ds,
                    validation_data=val_ds_v,
                    batch_size=BATCH_SIZE,
                    class_weight=class_weights_dict,
                    epochs=NUM_EPOCHS)
# Out:
# Epoch 1/100
# 86/86 [==============================] - 55s 482ms/step - loss: 1.2191 - accuracy: 0.5142 - precision: 0.6836 - recall: 0.2564 - auc: 0.7432 - f1_score: 0.3527 - val_loss: 0.9464 - val_accuracy: 0.6788 - val_precision: 0.7745 - val_recall: 0.5416 - val_auc: 0.8850 - val_f1_score: 0.5170
# Epoch 2/100
# 86/86 [==============================] - 43s 465ms/step - loss: 1.1063 - accuracy: 0.5718 - precision: 0.7063 - recall: 0.3641 - auc: 0.7986 - f1_score: 0.4615 - val_loss: 0.9142 - val_accuracy: 0.7255 - val_precision: 0.7476 - val_recall: 0.5577 - val_auc: 0.8965 - val_f1_score: 0.5986
# Epoch 3/100
# 86/86 [==============================] - 43s 465ms/step - loss: 1.0550 - accuracy: 0.6265 - precision: 0.7546 - recall: 0.4274 - auc: 0.8172 - f1_score: 0.5299 - val_loss: 0.8387 - val_accuracy: 0.7766 - val_precision: 0.8198 - val_recall: 0.6175 - val_auc: 0.9288 - val_f1_score: 0.6769
# Epoch 4/100
# 86/86 [==============================] - 43s 467ms/step - loss: 1.0164 - accuracy: 0.6426 - precision: 0.7723 - recall: 0.4492 - auc: 0.8365 - f1_score: 0.5760 - val_loss: 0.7970 - val_accuracy: 0.7109 - val_precision: 0.7348 - val_recall: 0.6511 - val_auc: 0.9302 - val_f1_score: 0.6730
# Epoch 5/100
# 86/86 [==============================] - 44s 467ms/step - loss: 0.9537 - accuracy: 0.6634 - precision: 0.7780 - recall: 0.4810 - auc: 0.8571 - f1_score: 0.6133 - val_loss: 0.7533 - val_accuracy: 0.7781 - val_precision: 0.8051 - val_recall: 0.7416 - val_auc: 0.9434 - val_f1_score: 0.7509
# Epoch 6/100
# 86/86 [==============================] - 43s 465ms/step - loss: 0.9048 - accuracy: 0.7144 - precision: 0.8000 - recall: 0.5434 - auc: 0.8782 - f1_score: 0.6647 - val_loss: 0.7142 - val_accuracy: 0.8307 - val_precision: 0.8454 - val_recall: 0.7504 - val_auc: 0.9615 - val_f1_score: 0.7886
100
# 86/86 [==============================] - 44s 466ms/step - loss: 0.6661 - accuracy: 0.8443 - precision: 0.9033 - recall: 0.7161 - auc: 0.9256 - f1_score: 0.8341 - val_loss: 0.5607 - val_accuracy: 0.8745 - val_precision: 0.8857 - val_recall: 0.8599 - val_auc: 0.9842 - val_f1_score: 0.8716
# Epoch 37/100
# 86/86 [==============================] - 44s 466ms/step - loss: 0.6635 - accuracy: 0.8450 - precision: 0.9084 - recall: 0.7075 - auc: 0.9256 - f1_score: 0.8353 - val_loss: 0.5715 - val_accuracy: 0.8657 - val_precision: 0.8832 - val_recall: 0.8496 - val_auc: 0.9818 - val_f1_score: 0.8654
# Epoch 38/100
# 86/86 [==============================] - 44s 466ms/step - loss: 0.6449 - accuracy: 0.8581 - precision: 0.9171 - recall: 0.7139 - auc: 0.9312 - f1_score: 0.8464 - val_loss: 0.5306 - val_accuracy: 0.9051 - val_precision: 0.9136 - val_recall: 0.8949 - val_auc: 0.9871 - val_f1_score: 0.8973
# Epoch 39/100
# 86/86 [==============================] - 44s 466ms/step - loss: 0.6210 - accuracy: 0.8731 - precision: 0.9255 - recall: 0.7273 - auc: 0.9295 - f1_score: 0.8587 - val_loss: 0.5370 - val_accuracy: 0.9007 - val_precision: 0.9130 - val_recall: 0.8891 - val_auc: 0.9840 - val_f1_score: 0.8925
# Epoch 40/100
# 86/86 [==============================] - 44s 468ms/step - loss: 0.6384 - accuracy: 0.8592 - precision: 0.9188 - recall: 0.7163 - auc: 0.9288 - f1_score: 0.8445 - val_loss: 0.5261 - val_accuracy: 0.9139 - val_precision: 0.9199 - val_recall: 0.9051 - val_auc: 0.9866 - val_f1_score: 0.9084
# Epoch 41/100
# 86/86 [==============================] - 44s 465ms/step - loss: 0.6160 - accuracy: 0.8716 - precision: 0.9205 - recall: 0.7299 - auc: 0.9347 - f1_score: 0.8599 - val_loss: 0.5602 - val_accuracy: 0.9007 - val_precision: 0.9136 - val_recall: 0.8949 - val_auc: 0.9805 - val_f1_score: 0.8963
# Epoch 42/100
# 86/86 [==============================] - 44s 466ms/step - loss: 0.6280 - accuracy: 0.8694 - precision: 0.9247 - recall: 0.7269 - auc: 0.9290 - f1_score: 0.8561 - val_loss: 0.5248 - val_accuracy: 0.9109 - val_precision: 0.9170 - val_recall: 0.9036 - val_auc: 0.9881 - val_f1_score: 0.9047
# Epoch 43/100
# 86/86 [==============================] - 44s 466ms/step - loss: 0.6272 - accuracy: 0.8621 - precision: 0.9245 - recall: 0.7247 - auc: 0.9363 - f1_score: 0.8514 - val_loss: 0.5551 - val_accuracy: 0.8905 - val_precision: 0.9076 - val_recall: 0.8745 - val_auc: 0.9858 - val_f1_score: 0.8900
# Epoch 44/100
# 86/86 [==============================] - 44s 465ms/step - loss: 0.6108 - accuracy: 0.8771 - precision: 0.9271 - recall: 0.7390 - auc: 0.9370 - f1_score: 0.8619 - val_loss: 0.5225 - val_accuracy: 0.9051 - val_precision: 0.9204 - val_recall: 0.8949 - val_auc: 0.9868 - val_f1_score: 0.9026
# Epoch 45/100
# 86/86 [==============================] - 44s 466ms/step - loss: 0.6168 - accuracy: 0.8778 - precision: 0.9328 - recall: 0.7394 - auc: 0.9320 - f1_score: 0.8698 - val_loss: 0.5631 - val_accuracy: 0.8891 - val_precision: 0.9018 - val_recall: 0.8584 - val_auc: 0.9830 - val_f1_score: 0.8798
# Epoch 46/100
# 86/86 [==============================] - 44s 466ms/step - loss: 0.
100
# 86/86 [==============================] - 43s 464ms/step - loss: 0.5452 - accuracy: 0.9106 - precision: 0.9541 - recall: 0.7757 - auc: 0.9467 - f1_score: 0.9001 - val_loss: 0.5467 - val_accuracy: 0.9051 - val_precision: 0.9112 - val_recall: 0.8993 - val_auc: 0.9827 - val_f1_score: 0.9001
# Epoch 69/100
# 86/86 [==============================] - 44s 465ms/step - loss: 0.5670 - accuracy: 0.8997 - precision: 0.9459 - recall: 0.7603 - auc: 0.9390 - f1_score: 0.8913 - val_loss: 0.5885 - val_accuracy: 0.8803 - val_precision: 0.8952 - val_recall: 0.8730 - val_auc: 0.9762 - val_f1_score: 0.8775
# Epoch 70/100
# 86/86 [==============================] - 43s 464ms/step - loss: 0.5592 - accuracy: 0.9023 - precision: 0.9520 - recall: 0.7723 - auc: 0.9411 - f1_score: 0.8939 - val_loss: 0.5717 - val_accuracy: 0.8730 - val_precision: 0.8844 - val_recall: 0.8599 - val_auc: 0.9815 - val_f1_score: 0.8700
# Epoch 71/100
# 86/86 [==============================] - 44s 464ms/step - loss: 0.5690 - accuracy: 0.9048 - precision: 0.9485 - recall: 0.7616 - auc: 0.9389 - f1_score: 0.8925 - val_loss: 0.5290 - val_accuracy: 0.9036 - val_precision: 0.9148 - val_recall: 0.8934 - val_auc: 0.9851 - val_f1_score: 0.8981
# Epoch 72/100
# 86/86 [==============================] - 44s 465ms/step - loss: 0.5626 - accuracy: 0.9117 - precision: 0.9489 - recall: 0.7731 - auc: 0.9442 - f1_score: 0.8954 - val_loss: 0.5491 - val_accuracy: 0.9036 - val_precision: 0.9098 - val_recall: 0.8978 - val_auc: 0.9801 - val_f1_score: 0.8959
# Epoch 73/100
# 86/86 [==============================] - 44s 467ms/step - loss: 0.5575 - accuracy: 0.9074 - precision: 0.9486 - recall: 0.7662 - auc: 0.9428 - f1_score: 0.8941 - val_loss: 0.5367 - val_accuracy: 0.9124 - val_precision: 0.9154 - val_recall: 0.9007 - val_auc: 0.9859 - val_f1_score: 0.9032
# Epoch 74/100
# 86/86 [==============================] - 44s 467ms/step - loss: 0.5566 - accuracy: 0.9088 - precision: 0.9544 - recall: 0.7716 - auc: 0.9428 - f1_score: 0.8974 - val_loss: 0.5120 - val_accuracy: 0.9139 - val_precision: 0.9174 - val_recall: 0.9080 - val_auc: 0.9892 - val_f1_score: 0.9083
# Epoch 75/100
# 86/86 [==============================] - 44s 467ms/step - loss: 0.5429 - accuracy: 0.9143 - precision: 0.9552 - recall: 0.7818 - auc: 0.9471 - f1_score: 0.9059 - val_loss: 0.5269 - val_accuracy: 0.9080 - val_precision: 0.9126 - val_recall: 0.8993 - val_auc: 0.9879 - val_f1_score: 0.9038
# Epoch 76/100
# 86/86 [==============================] - 44s 467ms/step - loss: 0.5509 - accuracy: 0.9066 - precision: 0.9525 - recall: 0.7687 - auc: 0.9437 - f1_score: 0.8978 - val_loss: 0.5792 - val_accuracy: 0.8803 - val_precision: 0.8846 - val_recall: 0.8730 - val_auc: 0.9822 - val_f1_score: 0.8763
# Epoch 77/100
# 86/86 [==============================] - 44s 464ms/step - loss: 0.5390 - accuracy: 0.9128 - precision: 0.9570 - recall: 0.7800 - auc: 0.9446 - f1_score: 0.9046 - val_loss: 0.5139 - val_accuracy: 0.9168 - val_precision: 0.9217 - val_recall: 0.9109 - val_auc: 0.9876 - val_f1_score: 0.9120
# Epoch 78/100
# 86/86 [==============================] - 44s 466ms/step - loss: 0
# 86/86 [==============================] - 44s 465ms/step - loss: 0.5459 - accuracy: 0.9128 - precision: 0.9606 - recall: 0.7830 - auc: 0.9415 - f1_score: 0.9078 - val_loss: 0.6510 - val_accuracy: 0.8482 - val_precision: 0.8571 - val_recall: 0.8409 - val_auc: 0.9684 - val_f1_score: 0.8485
# Epoch 99/100
# 86/86 [==============================] - 44s 464ms/step - loss: 0.5329 - accuracy: 0.9198 - precision: 0.9578 - recall: 0.7799 - auc: 0.9447 - f1_score: 0.9111 - val_loss: 0.5479 - val_accuracy: 0.8964 - val_precision: 0.9040 - val_recall: 0.8934 - val_auc: 0.9838 - val_f1_score: 0.8945
# Epoch 100/100
# 86/86 [==============================] - 43s 464ms/step - loss: 0.5378 - accuracy: 0.9143 - precision: 0.9518 - recall: 0.7768 - auc: 0.9434 - f1_score: 0.9035 - val_loss: 0.5831 - val_accuracy: 0.8715 - val_precision: 0.8832 - val_recall: 0.8613 - val_auc: 0.9780 - val_f1_score: 0.8695

# %% [markdown]
# ## Let's visualize the training progress of the model.

# %%
plot_training_curves(history, 'MS-Trust-CutMix (Both Modalities)')

# %% [markdown]
# ---
# # ⚓ RandAug

# %% [markdown]
# ## Model training and evaluation

# %%
model = create_cct_model()
#model.summary()

# %%
optimizer = tfa.optimizers.AdamW(learning_rate=0.001, weight_decay=0.0001)

model.compile(
    optimizer=optimizer,
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.Precision(),
        keras.metrics.Recall(),
        keras.metrics.AUC(),
        tfa.metrics.F1Score(num_classes=NUM_CLASSES, average='macro', threshold=0.5),
        ],
    )
history = model.fit(randaug_ds,
                    validation_data=val_ds_v,
                    batch_size=BATCH_SIZE,
                    class_weight=class_weights_dict,
                    epochs=50)
# Out:
# Epoch 1/50
# 86/86 [==============================] - 321s 1s/step - loss: 1.3877 - accuracy: 0.3381 - precision: 0.4223 - recall: 0.0387 - auc: 0.6040 - f1_score: 0.0674 - val_loss: 0.9690 - val_accuracy: 0.6993 - val_precision: 0.7922 - val_recall: 0.4453 - val_auc: 0.8883 - val_f1_score: 0.4085
# Epoch 2/50
# 86/86 [==============================] - 45s 481ms/step - loss: 1.2679 - accuracy: 0.4271 - precision: 0.6878 - recall: 0.1783 - auc: 0.7030 - f1_score: 0.2566 - val_loss: 0.8920 - val_accuracy: 0.7358 - val_precision: 0.7857 - val_recall: 0.6263 - val_auc: 0.9027 - val_f1_score: 0.6150
# Epoch 3/50
# 86/86 [==============================] - 45s 480ms/step - loss: 1.2310 - accuracy: 0.4537 - precision: 0.6834 - recall: 0.2031 - auc: 0.7286 - f1_score: 0.2901 - val_loss: 0.8768 - val_accuracy: 0.7124 - val_precision: 0.8247 - val_recall: 0.5839 - val_auc: 0.9155 - val_f1_score: 0.5730
# Epoch 4/50
# 86/86 [==============================] - 45s 482ms/step - loss: 1.2244 - accuracy: 0.4588 - precision: 0.6869 - recall: 0.2104 - auc: 0.7344 - f1_score: 0.3000 - val_loss: 0.8341 - val_accuracy: 0.7343 - val_precision: 0.7981 - val_recall: 0.6175 - val_auc: 0.9269 - val_f1_score: 0.6312
# Epoch 5/50
# 86/86 [==============================] - 45s 480ms/step - loss: 1.2113 - accuracy: 0.4661 - precision: 0.6957 - recall: 0.2217 - auc: 0.7430 - f1_score: 0.3194 - val_loss: 0.8086 - val_accuracy: 0.7606 - val_precision: 0.8000 - val_recall: 0.7124 - val_auc: 0.9291 - val_f1_score: 0.7314
# Epoch 6/50
# 86/86 [==============================] - 45s 480ms/step - loss: 1.1860 - accuracy: 0.4850 - precision: 0.7223 - recall: 0.2571 - auc: 0.7610 - f1_score: 0.3508 - val_loss: 0.8597 - val_accuracy: 0.7255 - val_precision: 0.7764 - val_recall: 0.6438 - val_auc: 0.9176 - val_f1_score: 0.6933
# Epoch 7/50
# 86/86 [==============================] - 45s 481ms/step - loss: 1.1722 - accuracy: 0.4934 - precision: 0.7151 - recall: 0.2619 - auc: 0.7714 - f1_score: 0.3699 - val_loss: 0.7918 - val_accuracy: 0.7679 - val_precision: 0.8237 - val_recall: 0.6686 - val_auc: 0.9337 - val_f1_score: 0.6798
# Epoch 8/50
# 86/86 [==============================] - 45s 478ms/step - loss: 1.1666 - accuracy: 0.4956 - precision: 0.7054 - recall: 0.2699 - auc: 0.7776 - f1_score: 0.3759 - val_loss: 0.7872 - val_accuracy: 0.7723 - val_precision: 0.7937 - val_recall: 0.7022 - val_auc: 0.9375 - val_f1_score: 0.7117
# Epoch 9/50
# 86/86 [==============================] - 45s 478ms/step - loss: 1.1455 - accuracy: 0.5186 - precision: 0.7094 - recall: 0.2743 - auc: 0.7891 - f1_score: 0.3852 - val_loss: 0.7623 - val_accuracy: 0.7854 - val_precision: 0.8054 - val_recall: 0.7431 - val_auc: 0.9426 - val_f1_score: 0.7487
# Epoch 10/50
# 86/86 [==============================] - 45s 478ms/step - loss: 1.1156 - accuracy: 0.5357 - precision: 0.6929 - recall: 0.3151 - auc: 0.8087 - f1_score: 0.4261 - val_loss: 0.7418 - val_accuracy: 0.8058 - val_precision: 0.8387 - val_recall: 0.7285 - val_auc: 0.9519 - val_f1_score: 0.7660
# Epoch 11/50
# 86/86 [==============================] - 45s 481ms/step - loss: 1.1095 - accuracy: 0.5346 - precision: 0.6708 - recall: 0.3136 - auc: 0.8095 - f1_score: 0.4205 - val_loss: 0.7959 - val_accuracy: 0.6905 - val_precision: 0.7183 - val_recall: 0.6365 - val_auc: 0.9320 - val_f1_score: 0.6563
# Epoch 12/50
# 86/86 [==============================] - 45s 480ms/step - loss: 1.0443 - accuracy: 0.5784 - precision: 0.6979 - recall: 0.3775 - auc: 0.8440 - f1_score: 0.4858 - val_loss: 0.7748 - val_accuracy: 0.7168 - val_precision: 0.7257 - val_recall: 0.6759 - val_auc: 0.9386 - val_f1_score: 0.6897
# Epoch 13/50
# 86/86 [==============================] - 45s 481ms/step - loss: 1.0065 - accuracy: 0.6069 - precision: 0.7049 - recall: 0.4278 - auc: 0.8606 - f1_score: 0.5257 - val_loss: 0.7172 - val_accuracy: 0.8102 - val_precision: 0.8256 - val_recall: 0.7810 - val_auc: 0.9594 - val_f1_score: 0.7940
# Epoch 14/50
# 86/86 [==============================] - 45s 483ms/step - loss: 1.0105 - accuracy: 0.6065 - precision: 0.7235 - recall: 0.4351 - auc: 0.8603 - f1_score: 0.5382 - val_loss: 0.7300 - val_accuracy: 0.8234 - val_precision: 0.8455 - val_recall: 0.7752 - val_auc: 0.9500 - val_f1_score: 0.7849
# Epoch 15/50
# 86/86 [==============================] - 45s 482ms/step - loss: 0.9868 - accuracy: 0.6116 - precision: 0.7189 - recall: 0.4431 - auc: 0.8690 - f1_score: 0.5419 - val_loss: 0.7011 - val_accuracy: 0.8088 - val_precision: 0.8238 - val_recall: 0.7781 - val_auc: 0.9594 - val_f1_score: 0.7935
# Epoch 16/50
# 86/86 [==============================] - 45s 479ms/step - loss: 0.9924 - accuracy: 0.6098 - precision: 0.7198 - recall: 0.4562 - auc: 0.8667 - f1_score: 0.5510 - val_loss: 0.7015 - val_accuracy: 0.7971 - val_precision: 0.8058 - val_recall: 0.7752 - val_auc: 0.9586 - val_f1_score: 0.7830
# Epoch 17/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.9807 - accuracy: 0.6163 - precision: 0.7216 - recall: 0.4602 - auc: 0.8716 - f1_score: 0.5547 - val_loss: 0.7092 - val_accuracy: 0.7650 - val_precision: 0.7847 - val_recall: 0.7343 - val_auc: 0.9566 - val_f1_score: 0.7551
# Epoch 18/50
# 86/86 [==============================] - 45s 478ms/step - loss: 0.9674 - accuracy: 0.6244 - precision: 0.7194 - recall: 0.4778 - auc: 0.8764 - f1_score: 0.5686 - val_loss: 0.6765 - val_accuracy: 0.8292 - val_precision: 0.8389 - val_recall: 0.8058 - val_auc: 0.9649 - val_f1_score: 0.8088
# Epoch 19/50
# 86/86 [==============================] - 45s 477ms/step - loss: 0.9393 - accuracy: 0.6459 - precision: 0.7381 - recall: 0.5036 - auc: 0.8888 - f1_score: 0.5915 - val_loss: 0.6925 - val_accuracy: 0.8350 - val_precision: 0.8520 - val_recall: 0.7985 - val_auc: 0.9647 - val_f1_score: 0.8155
# Epoch 20/50
# 86/86 [==============================] - 45s 481ms/step - loss: 0.9460 - accuracy: 0.6579 - precision: 0.7389 - recall: 0.5026 - auc: 0.8871 - f1_score: 0.5897 - val_loss: 0.6902 - val_accuracy: 0.8204 - val_precision: 0.8388 - val_recall: 0.7898 - val_auc: 0.9679 - val_f1_score: 0.8113
# Epoch 21/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.9241 - accuracy: 0.6426 - precision: 0.7159 - recall: 0.5201 - auc: 0.8922 - f1_score: 0.5985 - val_loss: 0.7177 - val_accuracy: 0.7533 - val_precision: 0.7652 - val_recall: 0.7372 - val_auc: 0.9538 - val_f1_score: 0.7508
# Epoch 22/50
# 86/86 [==============================] - 45s 481ms/step - loss: 0.9413 - accuracy: 0.6357 - precision: 0.7304 - recall: 0.5029 - auc: 0.8861 - f1_score: 0.5928 - val_loss: 0.6660 - val_accuracy: 0.8190 - val_precision: 0.8415 - val_recall: 0.8058 - val_auc: 0.9678 - val_f1_score: 0.8169
# Epoch 23/50
# 86/86 [==============================] - 45s 481ms/step - loss: 0.9184 - accuracy: 0.6470 - precision: 0.7153 - recall: 0.5241 - auc: 0.8939 - f1_score: 0.6006 - val_loss: 0.6430 - val_accuracy: 0.8350 - val_precision: 0.8509 - val_recall: 0.8248 - val_auc: 0.9740 - val_f1_score: 0.8288
# Epoch 24/50
# 86/86 [==============================] - 45s 482ms/step - loss: 0.8939 - accuracy: 0.6707 - precision: 0.7465 - recall: 0.5594 - auc: 0.9038 - f1_score: 0.6345 - val_loss: 0.6577 - val_accuracy: 0.8350 - val_precision: 0.8452 - val_recall: 0.8131 - val_auc: 0.9710 - val_f1_score: 0.8213
# Epoch 25/50
# 86/86 [==============================] - 45s 478ms/step - loss: 0.8952 - accuracy: 0.6754 - precision: 0.7460 - recall: 0.5496 - auc: 0.9037 - f1_score: 0.6283 - val_loss: 0.6722 - val_accuracy: 0.7723 - val_precision: 0.7978 - val_recall: 0.7489 - val_auc: 0.9634 - val_f1_score: 0.7663
# Epoch 26/50
# 86/86 [==============================] - 45s 477ms/step - loss: 0.9029 - accuracy: 0.6637 - precision: 0.7219 - recall: 0.5387 - auc: 0.8996 - f1_score: 0.6116 - val_loss: 0.6398 - val_accuracy: 0.8409 - val_precision: 0.8535 - val_recall: 0.8248 - val_auc: 0.9748 - val_f1_score: 0.8300
# Epoch 27/50
# 86/86 [==============================] - 45s 477ms/step - loss: 0.8965 - accuracy: 0.6645 - precision: 0.7450 - recall: 0.5667 - auc: 0.9019 - f1_score: 0.6404 - val_loss: 0.6554 - val_accuracy: 0.8409 - val_precision: 0.8556 - val_recall: 0.8044 - val_auc: 0.9693 - val_f1_score: 0.8253
# Epoch 28/50
# 86/86 [==============================] - 45s 478ms/step - loss: 0.8901 - accuracy: 0.6791 - precision: 0.7558 - recall: 0.5554 - auc: 0.9053 - f1_score: 0.6350 - val_loss: 0.6317 - val_accuracy: 0.8219 - val_precision: 0.8445 - val_recall: 0.8088 - val_auc: 0.9729 - val_f1_score: 0.8197
# Epoch 29/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.8757 - accuracy: 0.6875 - precision: 0.7455 - recall: 0.5704 - auc: 0.9100 - f1_score: 0.6419 - val_loss: 0.6390 - val_accuracy: 0.8234 - val_precision: 0.8467 - val_recall: 0.7985 - val_auc: 0.9723 - val_f1_score: 0.8192
# Epoch 30/50
# 86/86 [==============================] - 45s 483ms/step - loss: 0.8823 - accuracy: 0.6765 - precision: 0.7404 - recall: 0.5616 - auc: 0.9063 - f1_score: 0.6368 - val_loss: 0.6424 - val_accuracy: 0.8365 - val_precision: 0.8479 - val_recall: 0.8219 - val_auc: 0.9747 - val_f1_score: 0.8294
# Epoch 31/50
# 86/86 [==============================] - 45s 482ms/step - loss: 0.8874 - accuracy: 0.6743 - precision: 0.7379 - recall: 0.5554 - auc: 0.9039 - f1_score: 0.6290 - val_loss: 0.6227 - val_accuracy: 0.8599 - val_precision: 0.8660 - val_recall: 0.8394 - val_auc: 0.9744 - val_f1_score: 0.8413
# Epoch 32/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.8719 - accuracy: 0.6853 - precision: 0.7535 - recall: 0.5762 - auc: 0.9113 - f1_score: 0.6482 - val_loss: 0.6357 - val_accuracy: 0.8496 - val_precision: 0.8652 - val_recall: 0.8336 - val_auc: 0.9742 - val_f1_score: 0.8414
# Epoch 33/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.8666 - accuracy: 0.6867 - precision: 0.7540 - recall: 0.5879 - auc: 0.9130 - f1_score: 0.6550 - val_loss: 0.6295 - val_accuracy: 0.8467 - val_precision: 0.8650 - val_recall: 0.8234 - val_auc: 0.9770 - val_f1_score: 0.8346
# Epoch 34/50
# 86/86 [==============================] - 45s 479ms/step - loss: 0.8811 - accuracy: 0.6783 - precision: 0.7442 - recall: 0.5729 - auc: 0.9082 - f1_score: 0.6414 - val_loss: 0.6456 - val_accuracy: 0.8467 - val_precision: 0.8530 - val_recall: 0.8219 - val_auc: 0.9729 - val_f1_score: 0.8334
# Epoch 35/50
# 86/86 [==============================] - 45s 477ms/step - loss: 0.8753 - accuracy: 0.6718 - precision: 0.7382 - recall: 0.5697 - auc: 0.9089 - f1_score: 0.6386 - val_loss: 0.6322 - val_accuracy: 0.8540 - val_precision: 0.8647 - val_recall: 0.8394 - val_auc: 0.9764 - val_f1_score: 0.8465
# Epoch 36/50
# 86/86 [==============================] - 45s 479ms/step - loss: 0.8634 - accuracy: 0.6867 - precision: 0.7594 - recall: 0.5813 - auc: 0.9139 - f1_score: 0.6546 - val_loss: 0.6318 - val_accuracy: 0.8277 - val_precision: 0.8326 - val_recall: 0.8058 - val_auc: 0.9723 - val_f1_score: 0.8157
# Epoch 37/50
# 86/86 [==============================] - 45s 481ms/step - loss: 0.8563 - accuracy: 0.6937 - precision: 0.7515 - recall: 0.5999 - auc: 0.9156 - f1_score: 0.6623 - val_loss: 0.6345 - val_accuracy: 0.8467 - val_precision: 0.8618 - val_recall: 0.8190 - val_auc: 0.9776 - val_f1_score: 0.8351
# Epoch 38/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.8603 - accuracy: 0.6885 - precision: 0.7616 - recall: 0.5883 - auc: 0.9141 - f1_score: 0.6609 - val_loss: 0.6331 - val_accuracy: 0.8438 - val_precision: 0.8628 - val_recall: 0.8263 - val_auc: 0.9743 - val_f1_score: 0.8423
# Epoch 39/50
# 86/86 [==============================] - 45s 481ms/step - loss: 0.8596 - accuracy: 0.6867 - precision: 0.7500 - recall: 0.5952 - auc: 0.9151 - f1_score: 0.6572 - val_loss: 0.6288 - val_accuracy: 0.8409 - val_precision: 0.8556 - val_recall: 0.8307 - val_auc: 0.9767 - val_f1_score: 0.8369
# Epoch 40/50
# 86/86 [==============================] - 45s 481ms/step - loss: 0.8621 - accuracy: 0.7039 - precision: 0.7760 - recall: 0.6003 - auc: 0.9158 - f1_score: 0.6719 - val_loss: 0.6174 - val_accuracy: 0.8511 - val_precision: 0.8623 - val_recall: 0.8321 - val_auc: 0.9753 - val_f1_score: 0.8409
# Epoch 41/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.8561 - accuracy: 0.6940 - precision: 0.7516 - recall: 0.5894 - auc: 0.9157 - f1_score: 0.6567 - val_loss: 0.6047 - val_accuracy: 0.8584 - val_precision: 0.8711 - val_recall: 0.8482 - val_auc: 0.9786 - val_f1_score: 0.8494
# Epoch 42/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.8465 - accuracy: 0.6915 - precision: 0.7570 - recall: 0.6010 - auc: 0.9180 - f1_score: 0.6663 - val_loss: 0.6129 - val_accuracy: 0.8511 - val_precision: 0.8660 - val_recall: 0.8394 - val_auc: 0.9780 - val_f1_score: 0.8438
# Epoch 43/50
# 86/86 [==============================] - 45s 481ms/step - loss: 0.8384 - accuracy: 0.7075 - precision: 0.7601 - recall: 0.6149 - auc: 0.9215 - f1_score: 0.6774 - val_loss: 0.6194 - val_accuracy: 0.8540 - val_precision: 0.8675 - val_recall: 0.8409 - val_auc: 0.9765 - val_f1_score: 0.8443
# Epoch 44/50
# 86/86 [==============================] - 45s 481ms/step - loss: 0.8516 - accuracy: 0.6922 - precision: 0.7582 - recall: 0.5970 - auc: 0.9169 - f1_score: 0.6627 - val_loss: 0.5958 - val_accuracy: 0.8540 - val_precision: 0.8666 - val_recall: 0.8438 - val_auc: 0.9798 - val_f1_score: 0.8473
# Epoch 45/50
# 86/86 [==============================] - 45s 478ms/step - loss: 0.8586 - accuracy: 0.6878 - precision: 0.7544 - recall: 0.5813 - auc: 0.9146 - f1_score: 0.6546 - val_loss: 0.6022 - val_accuracy: 0.8555 - val_precision: 0.8666 - val_recall: 0.8438 - val_auc: 0.9788 - val_f1_score: 0.8457
# Epoch 46/50
# 86/86 [==============================] - 45s 478ms/step - loss: 0.8550 - accuracy: 0.6962 - precision: 0.7565 - recall: 0.6028 - auc: 0.9163 - f1_score: 0.6648 - val_loss: 0.6075 - val_accuracy: 0.8599 - val_precision: 0.8729 - val_recall: 0.8423 - val_auc: 0.9799 - val_f1_score: 0.8534
# Epoch 47/50
# 86/86 [==============================] - 45s 477ms/step - loss: 0.8508 - accuracy: 0.6889 - precision: 0.7573 - recall: 0.6054 - auc: 0.9170 - f1_score: 0.6699 - val_loss: 0.6022 - val_accuracy: 0.8496 - val_precision: 0.8582 - val_recall: 0.8394 - val_auc: 0.9777 - val_f1_score: 0.8366
# Epoch 48/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.8325 - accuracy: 0.7133 - precision: 0.7763 - recall: 0.6240 - auc: 0.9236 - f1_score: 0.6884 - val_loss: 0.6032 - val_accuracy: 0.8730 - val_precision: 0.8864 - val_recall: 0.8540 - val_auc: 0.9800 - val_f1_score: 0.8665
# Epoch 49/50
# 86/86 [==============================] - 45s 480ms/step - loss: 0.8209 - accuracy: 0.7144 - precision: 0.7819 - recall: 0.6317 - auc: 0.9275 - f1_score: 0.6935 - val_loss: 0.5941 - val_accuracy: 0.8657 - val_precision: 0.8705 - val_recall: 0.8438 - val_auc: 0.9801 - val_f1_score: 0.8464
# Epoch 50/50
# 86/86 [==============================] - 45s 481ms/step - loss: 0.8284 - accuracy: 0.7061 - precision: 0.7682 - recall: 0.6069 - auc: 0.9252 - f1_score: 0.6727 - val_loss: 0.6047 - val_accuracy: 0.8657 - val_precision: 0.8765 - val_recall: 0.8496 - val_auc: 0.9789 - val_f1_score: 0.8572

# %% [markdown]
# ## Let's visualize the training progress of the model.

# %%
plot_training_curves(history, 'MS-Trust-CutMix (Myelitis Classification)')
